# %%
import plotly.graph_objects as go
import copy as cp
from pprint import pprint
from gurobipy import *
from random import *
import numpy as np
from numpy import *
import matplotlib.pyplot as plt
import time
from itertools import groupby,chain
import itertools
import pandas as pd
from pandas import *
import networkx as nx
import random
from random import shuffle
from itertools import chain
import string
import json
from dataclasses import dataclass
import uuid
import bisect
from datetime import datetime

# %%
delta = 0.05
update_interval = 2
rcl_parameter = 0.3
llambda = 0.7

# %%
graph_top_left = [x for x in chain(range(0,11), range(27,38),range(54,65),range(81,92),range(108,119),range(135,146),range(162,173),range(189,200),range(216,227),range(243,254),range(270,281),range(297,308),range(324,335),range(351,362))]
graph_top_right = [x for x in chain(range(378,389),range(405,416),range(432,443),range(459,470),range(486,497),range(513,524),range(540,551),range(567,578),range(594,605),range(621,632),range(648,658),range(675,686),range(702,712))]
graph_center = [x for x in chain(range(200,208), range(227,234),range(253,261),range(281,289),range(308,316),range(335,343),range(362,370),range(389,397),range(416,424),range(443,451),range(470,478),range(497,505),range(524,532))]
graph_left  = [x for x in chain(range(11,19), range(38,46),range(65,73),range(92,100),range(119,127),range(146,154),range(173,181))]
graph_right = [x for x in chain(range(551,559), range(578,586),range(605,613),range(632,640),range(659,667),range(686,694),range(713,721))]
graph_bottom_left = [x for x in chain(range(19,27), range(46,54),range(73,81),range(100,108),range(127,135),range(154,162),range(181,189),range(208,216),range(235,243),range(262,270),range(289,297),range(316,324),range(343,351),range(370,378))]
graph_bottom_right = [x for x in chain(range(397,405),range(424,432),range(451,459),range(478,486),range(505,513),range(532,540),range(559,567),range(586,594),range(613,621),range(640,648),range(667,675),range(694,702),range(721,728))]

# %%
N = 5
G1 = nx.grid_2d_graph(N,N)

labels=dict(((i,j),i + (N-1-j)*N) for i, j in G1.nodes())
nx.relabel_nodes(G1,labels,False) #False=relabel the nodes in place
inds=labels.keys()
vals=labels.values()
inds=[(N-j-1,N-i-1) for i,j in inds]

#Create the dictionary of positions for the grid
grid_pos=dict(zip(vals,inds)) #Format: {node ID:(i,j)}

random.seed(511566511)
nodes = list(G1.nodes)
edges = list(G1.edges)

# top_left_remove = random.sample(graph_top_left,20)
# top_right_remove = random.sample(graph_top_right,10)
# bottom_left_remove = random.sample(graph_bottom_left,25)
# bottom_right_remove = random.sample(graph_bottom_right,35)
# center_remove = random.sample(graph_center,50)
# left_remove =random.sample(graph_left,50)
# right_remove = random.sample(graph_right,50)

# while nx.is_connected(G1) == True:
#     while len(G1) > 20:
    


#         if len(list(nx.isolates(G1)))>0:
#             G1.remove_nodes_from(list(nx.isolates(G1)))
#         if nx.is_connected(G1) == False:
#             G1 = G1_C
#         else:
#             G1_C=G1.copy()
#         if len(G1) <= 20:
#                 break


#Create the dictionary of positions for the grid
grid_pos=dict(zip(vals,inds)) #Format: {node ID:(i,j)}


# G1.remove_node(11)
# G1.remove_node(8)
# G1.remove_node(18)


#Clean the dictionaries in accordance with how we changed the original graph
for i in list(grid_pos):
    if i not in G1.nodes:
        grid_pos.pop(i)
        
coords = []
for i in inds:
    for key, value in grid_pos.items():
        if i == value:
            coords.append(i)

# %%
N = 27
G1 = nx.grid_2d_graph(N,N)

labels=dict(((i,j),i + (N-1-j)*N) for i, j in G1.nodes())
nx.relabel_nodes(G1,labels,False) #False=relabel the nodes in place
inds=labels.keys()
vals=labels.values()
inds=[(N-j-1,N-i-1) for i,j in inds]

#Create the dictionary of positions for the grid
grid_pos=dict(zip(vals,inds)) #Format: {node ID:(i,j)}

random.seed(123522)
nodes = list(G1.nodes)
edges = list(G1.edges)

# top_left_remove = random.sample(graph_top_left,20)
# top_right_remove = random.sample(graph_top_right,10)
# bottom_left_remove = random.sample(graph_bottom_left,25)
# bottom_right_remove = random.sample(graph_bottom_right,35)
center_remove = random.sample(graph_center,50)
left_remove =random.sample(graph_left,50)
right_remove = random.sample(graph_right,50)

while nx.is_connected(G1) == True:
    while len(G1) > 500:
    

    #     G12.remove_nodes_from(top_left_remove)
    #     G12.remove_nodes_from(top_right_remove)
    #     G12.remove_nodes_from(bottom_left_remove)
    #     G12.remove_nodes_from(bottom_right_remove)
#         G1.remove_nodes_from(center_remove)
#         G1.remove_nodes_from(left_remove)
#         G1.remove_nodes_from(right_remove)
        G1.remove_node(random.choice(list(G1.nodes)))
        if len(list(nx.isolates(G1)))>0:
            G1.remove_nodes_from(list(nx.isolates(G1)))
#         if nx.is_connected(G26) == False:
#             G26 = G26_C
#         else:
#             G26_C=G26.copy()
#     if len(G26) <= 500:
#             break


#Create the dictionary of positions for the grid
grid_pos=dict(zip(vals,inds)) #Format: {node ID:(i,j)}


G1.add_edge(659,657)
G1.add_edge(633,579)
G1.add_edge(690,636)





#Clean the dictionaries in accordance with how we changed the original graph
for i in list(grid_pos):
    if i not in G1.nodes:
        grid_pos.pop(i)
        
coords = []
for i in inds:
    for key, value in grid_pos.items():
        if i == value:
            coords.append(i)

# %%
def get_furthest_nodes(G):
    sp_length = {} # dict containing shortest path distances for each pair of nodes
    diameter = None # will contain the graphs diameter (length of longest shortest path)
    furthest_node_list = [] # will contain list of tuple of nodes with shortest path equal to diameter
    
    for node in G.nodes:
        # Get the shortest path from node to all other nodes
        sp_length[node] = nx.single_source_dijkstra_path_length(G,node, weight = 'distance')
        longest_path = max(sp_length[node].values()) # get length of furthest node from node
        
        # Update diameter when necessary (on first iteration and when we find a longer one)
        if diameter == None:
            diameter = longest_path # set the first diameter
            
        # update the list of tuples of furthest nodes if we have a best diameter
        if longest_path >= diameter:
            diameter = longest_path
            
            # a list of tuples containing
            # the current node and the nodes furthest from it
            node_longest_paths = [(node,other_node)
                                      for other_node in sp_length[node].keys()
                                      if sp_length[node][other_node] == longest_path]
            if longest_path > diameter:
                # This is better than the previous diameter
                # so replace the list of tuples of diameter nodes with this nodes
                # tuple of furthest nodes
                furthest_node_list = node_longest_paths
            else: # this is equal to the current diameter
                # add this nodes tuple of furthest nodes to the current list    
                furthest_node_list = furthest_node_list + node_longest_paths
                
    # return the diameter,
        # all pairs of nodes with shortest path length equal to the diameter
        # the dict of all-node shortest paths
    return({'diameter':diameter,
            'furthest_node_list':furthest_node_list,
            'node_shortest_path_dicts':sp_length})

#Define a function to find the union of two lists
def Union(lst1,lst2):
    final_list = list(set(lst1) | set(lst2))
    return final_list

# %%
def plus_plus(ds, k):
    """
    Create cluster centroids using the k-means++ algorithm.
    Parameters
    ----------
    ds : numpy array
        The dataset to be used for centroid initialization.
    k : int
        The desired number of clusters for which centroids are required.
    Returns
    -------
    centroids : numpy array
        Collection of k centroids as a numpy array.
    Inspiration from here: https://stackoverflow.com/questions/5466323/how-could-one-implement-the-k-means-algorithm
    """
#     np.random.seed(random_state)
    centroids = [random.choice(ds)]

    for _ in range(1, k):
        dist_sq = np.array([min([np.inner(c-x,c-x) for c in centroids]) for x in ds])
        probs = dist_sq/dist_sq.sum()
        cumulative_probs = probs.cumsum()
        r = np.random.rand()
        
        for j, p in enumerate(cumulative_probs):
            if r < p:
                i = j
                break
        
        centroids.append(ds[i])

    return np.array(centroids)

# %%
N = 27
G1 = nx.grid_2d_graph(N,N)

labels=dict(((i,j),i + (N-1-j)*N) for i, j in G1.nodes())
nx.relabel_nodes(G1,labels,False) #False=relabel the nodes in place
inds=labels.keys()
vals=labels.values()
inds=[(N-j-1,N-i-1) for i,j in inds]

#Create the dictionary of positions for the grid
grid_pos=dict(zip(vals,inds)) #Format: {node ID:(i,j)}

random.seed(511566511)
nodes = list(G1.nodes)
edges = list(G1.edges)

# top_left_remove = random.sample(graph_top_left,20)
# top_right_remove = random.sample(graph_top_right,10)
# bottom_left_remove = random.sample(graph_bottom_left,25)
# bottom_right_remove = random.sample(graph_bottom_right,35)
center_remove = random.sample(graph_center,50)
left_remove =random.sample(graph_left,50)
right_remove = random.sample(graph_right,50)

while nx.is_connected(G1) == True:
    while len(G1) > 500:
    

    #     G12.remove_nodes_from(top_left_remove)
    #     G12.remove_nodes_from(top_right_remove)
    #     G12.remove_nodes_from(bottom_left_remove)
    #     G12.remove_nodes_from(bottom_right_remove)
        G1.remove_nodes_from(center_remove)
        G1.remove_nodes_from(left_remove)
        G1.remove_nodes_from(right_remove)
        G1.remove_node(random.choice(list(G1.nodes)))
        if len(list(nx.isolates(G1)))>0:
            G1.remove_nodes_from(list(nx.isolates(G1)))
#         if nx.is_connected(G26) == False:
#             G26 = G26_C
#         else:
#             G26_C=G26.copy()
#     if len(G26) <= 500:
#             break


#Create the dictionary of positions for the grid
grid_pos=dict(zip(vals,inds)) #Format: {node ID:(i,j)}

G1.add_edge(201,203)
G1.add_edge(258,256)
G1.add_edge(231,233)
G1.add_edge(496,500)
G1.add_edge(523,527)
G1.add_edge(527,529)
G1.add_edge(422,424)
G1.add_edge(449,451)
G1.add_edge(391,389)
G1.add_edge(365,363)


#Clean the dictionaries in accordance with how we changed the original graph
for i in list(grid_pos):
    if i not in G1.nodes:
        grid_pos.pop(i)
        
coords = []
for i in inds:
    for key, value in grid_pos.items():
        if i == value:
            coords.append(i)

# %%
plt.figure(3,figsize=(12,12))
nx.draw(G1, pos=grid_pos,with_labels = True)
plt.show()

# %%
def construction_grasp(delta, rcl_parameter,llambda,graph_input):
    #Choosing centers

    locations = np.array(coords)

    centroids = plus_plus(locations, 10)

    centroids = centroids.tolist()

    centroids_tuple = []
    for i in centroids:
        centroids_tuple.append(tuple((i)))

    centers_depots = []
    for i in centroids_tuple:
        for key, value in grid_pos.items():
            if i == value:
                centers_depots.append(key)

#     centers_depots = [0,20,24]
                
    #Initialize randomized activities
    combinations = list(itertools.combinations(centers_depots, 2))



    #Calculate the average for each activity
    adjacent = {}
    for i in graph_input.nodes():
            adjacent[i] = []
    for e in graph_input.edges():
        adjacent[e[0]].append(e)
        adjacent[e[1]].append(e)

    #Define adjacent nodes for each node

    adjacent_nodes = {}
    nodes_new = {}
    for i in adjacent:
        adjacent_nodes[i] = []
        for e in range(len(adjacent[i])):
            adjacent_nodes[i].append(adjacent[i][e][0])
            adjacent_nodes[i].append(adjacent[i][e][1])
    for i in adjacent_nodes:
        nodes_new[i] = list(set(adjacent_nodes[i]))
    adjacent_nodes = {k:[vi for vi in v if k != vi] for k,v in nodes_new.items()}



    random.seed(2021)
    demand= {}
    for v in graph_input.nodes:
        demand[v] = 1

    random.seed(2021)
    workload= {}
    for v in graph_input.nodes:
        workload[v] = 1

    random.seed(2021)
    n_customers= {}
    for v in graph_input.nodes:
        n_customers[v] = 1

#     random.seed(2021)
#     for v in centers_depots:
#         demand[v] = 400
#         workload[v] = 100
#         n_customers[v] = 20
#         for i in adjacent_nodes[v]:
#             demand[i] = random.randint(370,400)
#             workload[i] = random.randint(90,100)
#             n_customers[i] = random.randint(15,20)

#     random.seed(2021)
    distance= {}
    for e in graph_input.edges:
        distance[e] = 1


    nx.set_node_attributes(graph_input, values = n_customers, name = "n_customers")
    nx.set_node_attributes(graph_input, values = demand, name = "demand")
    nx.set_node_attributes(graph_input, values = workload, name = "workload")
    nx.set_edge_attributes(graph_input, values = distance, name = "distance")
    
    
    shortest_paths_dict = get_furthest_nodes(graph_input)['node_shortest_path_dicts']
    graph_diameter = get_furthest_nodes(graph_input)['diameter']

    total_workload = 0 
    for v in graph_input.nodes:
        total_workload = total_workload + graph_input.nodes[v]['workload']
    average_workload = total_workload/len(centers_depots)

    total_customers = 0 
    for v in graph_input.nodes:
        total_customers = total_customers + graph_input.nodes[v]['n_customers']
    average_customers = total_customers/len(centers_depots)

    total_demand = 0 
    for v in graph_input.nodes:
        total_demand = total_demand + graph_input.nodes[v]['demand']
    average_demand = total_demand/len(centers_depots)



    selected_nodes = {}
    near_nodes = {}
    for k in centers_depots:
        selected_nodes[k] = []
        selected_nodes[k] = nx.ego_graph(graph_input,k, radius = 1, center=False, undirected=True, distance='distance')
        near_nodes[k] = list(selected_nodes[k].nodes())

#     for v in near_nodes:
#         print(list(any(v in val for val in near_nodes.values())))

    #Find the percentage of selected nodes from the graph
    num_nodes = 0
    for i in near_nodes:
        num_nodes = num_nodes+len(near_nodes[i])

#     percentage_nodes = 1-(num_nodes/len(nodes))

    construction_time = time.time()

    #Create the initial districts by assigning the nodes in the neighborhood to depots
    district_customers = {}
    district_workload = {}
    district_demand = {}
    unassigned = set(graph_input.nodes) - set(centers_depots)
    neighborhood = {}
    district = {}
    rcl = {}
    i = 0
    while 0.7*len(graph_input.nodes) <= len(unassigned):
        print("In while loop")
#         district[0] = unassigned
        for k in centers_depots:
            district_customers[k]= 0
            district_workload[k] = 0
            district_demand[k] = 0
            neighborhood[k] = []
            neighborhood[k] = near_nodes[k]
            unassigned = unassigned-set(near_nodes[k])-set(centers_depots)
            district[k] = []
            district[k] = Union(district[k], neighborhood[k])
#Find the total of each activity for each district
        for w in district[k]:
            district_customers[k] = district_customers[k] + graph_input.nodes[w]['n_customers']
            district_workload[k] = district_workload[k] + graph_input.nodes[w]['workload']
            district_demand[k] = district_demand[k] + graph_input.nodes[w]['demand']
        print(district)
        print(len(unassigned))
                
            
    


    local_infeasible = 0

    for i in range(len(centers_depots)):
        local_infeasible = local_infeasible + ((1/average_customers)*max(district_customers[centers_depots[i]]-(1+delta)*average_customers,(1-delta)*average_customers-district_customers[centers_depots[i]],0))+\
            ((1/average_demand)*max(district_demand[centers_depots[i]]-(1+delta)*average_demand,(1-delta)*average_demand-district_demand[centers_depots[i]],0))+\
                ((1/average_workload)*max(district_workload[centers_depots[i]]-(1+delta)*average_workload,(1-delta)*average_workload-district_workload[centers_depots[i]],0))

    #Select a larger neighborhood for the depots
    larger_selected_nodes = {}
    larger_selected_nodes = {}
    for k in centers_depots:
        larger_selected_nodes[k] = []
        larger_selected_nodes[k] = nx.ego_graph(graph_input,k, radius = 4, center=False, undirected=True, distance='distance')
        larger_selected_nodes[k] = list(set(larger_selected_nodes[k].nodes())-set(district[k]))

    #Ensure that there is no overlap between the neighborhoods
    new_neighborhood = {}
    for k in centers_depots:
        new_neighborhood[k] = []
        for v in larger_selected_nodes[k]:
            x = list(any(v in val for val in new_neighborhood.values()))
            y = list(any(v in val for val in district.values()))
            if True not in x:
                if True not in y:             
                    new_neighborhood[k].append(v)



    #Find the infeasibility of each district
    infeasible = {}

    for k in district:
        infeasible[k] = {}
        for v in new_neighborhood[k]:
            infeasible[k][v] = (1/average_workload)*max(district_workload[k]+graph_input.nodes[v]['workload']-(1+delta)*average_workload,0)+\
                (1/average_customers)*max(district_customers[k]+graph_input.nodes[v]['n_customers']-(1+delta)*average_customers,0)+\
                    (1/average_demand)*max(district_demand[k]+graph_input.nodes[v]['demand']-(1+delta)*average_demand,0)

    obj_dispersion = max(shortest_paths_dict[x][y] for i in district for x in district[i] for y in district[i])
    frac_diameter = (1/graph_diameter)
    #Find the average dispersion of each district
    dispersion = {}
    for k in district:
        dispersion[k] = {}
        for v in new_neighborhood[k]:
            dispersion[k][v] = frac_diameter*max(obj_dispersion, max(shortest_paths_dict[x][y] for x in Union(district[k],[v]) for y in Union(district[k],[v])))

    phi = {}

    for k in district:
        phi[k] = {}
        for v in new_neighborhood[k]:
            phi[k][v] = llambda*dispersion[k][v]+(1-llambda)*infeasible[k][v]



    phi_min = {}
    for k in district:
        phi_min[k] = min(phi[k].values())

    phi_max = {}
    for k in district:
        phi_max[k] = max(phi[k].values())



    open_district = {}
    for k in district:
        open_district[k] = True

    #Create the restricted candidate list

    rcl = {}

    for k in district:
        rcl[k] = []
        if open_district[k] == True:
            for h in new_neighborhood[k]:
                if phi[k][h] <= phi_min[k]+rcl_parameter*(phi_max[k]-phi_min[k]):
                    rcl[k].append(h)

    x = 0
    r = 0
    i=0
    viable = False
    OR_OPEN = True
    RCL_EMPTY = True
    NOT_OPEN = False
    UNASSIGNED_REPEAT = False
    final_depot = False
    unassigned_length = len(unassigned)
    unassigned_previous = 0
    while ((len(unassigned) >0) and not NOT_OPEN and not UNASSIGNED_REPEAT):
        if unassigned_length == unassigned_previous:
            UNASSIGNED_REPEAT = True
#         print(unassigned_length)
        unassigned_previous = len(unassigned)
        for k in centers_depots:
            # print("First chosen depot k is")
            # print(k)
            # print("Length of RCL is")
            # print(len(rcl[k]))
            # print("The district is ")
            # print(open_district[k])

            if (len(rcl[k]) == 0):
                #print("RCL EMPTY: Going to next iteration.")
                continue

            if open_district[k]:
                for deleted in rcl[k]:
                    for i in district[k]:
                        if deleted in adjacent_nodes[i]:                        
                            if deleted in rcl[k]:
                                # print("Chosen RCL element is")
                                # print(deleted)
                                rcl[k].remove(deleted)            
                                district[k].append(deleted)
                                district_customers[k] = district_customers[k] + graph_input.nodes[deleted]['n_customers']
                                district_demand[k] = district_demand[k] + graph_input.nodes[deleted]['demand'] 
                                district_workload[k] = district_workload[k] + graph_input.nodes[deleted]['workload'] 
                                #unassigned_previous = len(unassigned)
                                if deleted in unassigned:
                                    unassigned.remove(deleted)
                                    unassigned_length = len(unassigned)
                                if (len(new_neighborhood[k]) <= 0) or (district_customers[k] >= average_customers+delta)\
                                        or (district_demand[k] >= average_demand+delta) or (district_workload[k] >= average_workload+delta):
                                    open_district[k] = False
            else:
                #print("District closed: Going to next iteration.")
                continue


        # if unassigned_length == unassigned_previous:
        #     UNASSIGNED_REPEAT = True
        # print(unassigned_length)
        # unassigned_previous = len(unassigned)




        if True not in open_district.values():
            NOT_OPEN = True

    #         RCL_EMPTY = False
    #         while len(rcl[depots[r]])<=0 and r<=len(depots):
    #             r = r+1
    #         if r <len(depots):
    #             RCL_EMPTY = True

#     for k in centers_depots:
#         for i in district[k]:
#             print(list(any(i in val for val in district.values())))




    a =  0
    unassigned = list(unassigned)
    for k in centers_depots:
        for x in district[k]:
            for v in unassigned:
                if v in adjacent_nodes[x]:
                    if open_district[k] == True:
                        unique_pls = list(any(v in val for val in district.values()))
                        if True not in unique_pls:
                            district[k].append(v)
                            unassigned.remove(v)
                            district_customers[k] = district_customers[k] + graph_input.nodes[v]['n_customers']
                            district_demand[k] = district_demand[k] + graph_input.nodes[v]['demand'] 
                            district_workload[k] = district_workload[k] + graph_input.nodes[v]['workload'] 
                            if (district_customers[k] >= average_customers+delta) or (district_demand[k] >= average_demand+delta) \
                                or (district_workload[k] >= average_workload+delta):
                                open_district[k] = False

                                

    
    a =  0
    unassigned = list(unassigned)
    for k in centers_depots:
        for x in district[k]:
            for v in unassigned:
                if v in adjacent_nodes[x]:
                    unique_pls = list(any(v in val for val in district.values()))
                    if True not in unique_pls:
                        district[k].append(v)
                        unassigned.remove(v)
                        district_customers[k] = district_customers[k] + graph_input.nodes[v]['n_customers']
                        district_demand[k] = district_demand[k] + graph_input.nodes[v]['demand'] 
                        district_workload[k] = district_workload[k] + graph_input.nodes[v]['workload'] 
                        if (district_customers[k] >= average_customers+delta) or (district_demand[k] >= average_demand+delta) \
                            or (district_workload[k] >= average_workload+delta):
                            open_district[k] = False

    unassigned = list(unassigned)
    #i = depots[0]
    #a = (a+1) % len(depots)
    for k in centers_depots:
        for x in district[k]:
            for v in unassigned:
                if v in adjacent_nodes[x]:
                    unique_pls = list(any(v in val for val in district.values()))
                    if True not in unique_pls:
                        district[k].append(v)
                        unassigned.remove(v)
                        district_customers[k] = district_customers[k] + graph_input.nodes[v]['n_customers']
                        district_demand[k] = district_demand[k] + graph_input.nodes[v]['demand'] 
                        district_workload[k] = district_workload[k] + graph_input.nodes[v]['workload'] 
                        if (district_customers[k] >= average_customers+delta) or (district_demand[k] >= average_demand+delta) \
                            or (district_workload[k] >= average_workload+delta):
                            open_district[k] = False

#     districts_keys = list(district.keys())
#     colorss = ["lightcoral","sandybrown","darkorange","lawngreen","green","aqua","steelblue","violet","purple","maroon"]

#     color_map = {}
#     for node in list(graph_input.nodes):
#         color_map[node] = "blue"
#         for k in range(len(districts_keys)):
#             if node in district[districts_keys[k]]:
#                 color_map[node] = colorss[k]
    

#     color_map = list(color_map.values())

#     plt.figure(3,figsize=(12,12))
#     nx.draw(graph_input,node_color=color_map, pos=grid_pos,with_labels = True)
#     plt.show()

    local_infeasible = 0

    for i in range(len(centers_depots)):
        local_infeasible = local_infeasible + ((1/average_customers)*max(district_customers[centers_depots[i]]-(1+delta)*average_customers,(1-delta)*average_customers-district_customers[centers_depots[i]],0))+\
            ((1/average_demand)*max(district_demand[centers_depots[i]]-(1+delta)*average_demand,(1-delta)*average_demand-district_demand[centers_depots[i]],0))+\
                ((1/average_workload)*max(district_workload[centers_depots[i]]-(1+delta)*average_workload,(1-delta)*average_workload-district_workload[centers_depots[i]],0))

    #print(local_infeasible)
    construction_obj = max(shortest_paths_dict[x][y] for i in district for x in district[i] for y in district[i])
    
    return district, centers_depots, combinations, adjacent_nodes, average_customers, average_demand,average_workload,shortest_paths_dict, construction_obj,local_infeasible

# %%
def construction_grasp(delta, rcl_parameter,llambda,graph_input):
    #Choosing centers

    locations = np.array(coords)

    centroids = plus_plus(locations, 10)

    centroids = centroids.tolist()

    centroids_tuple = []
    for i in centroids:
        centroids_tuple.append(tuple((i)))

    centers_depots = []
    for i in centroids_tuple:
        for key, value in grid_pos.items():
            if i == value:
                centers_depots.append(key)
                
    #Initialize randomized activities
    combinations = list(itertools.combinations(centers_depots, 2))



    #Calculate the average for each activity
    adjacent = {}
    for i in graph_input.nodes():
            adjacent[i] = []
    for e in graph_input.edges():
        adjacent[e[0]].append(e)
        adjacent[e[1]].append(e)

    #Define adjacent nodes for each node

    adjacent_nodes = {}
    nodes_new = {}
    for i in adjacent:
        adjacent_nodes[i] = []
        for e in range(len(adjacent[i])):
            adjacent_nodes[i].append(adjacent[i][e][0])
            adjacent_nodes[i].append(adjacent[i][e][1])
    for i in adjacent_nodes:
        nodes_new[i] = list(set(adjacent_nodes[i]))
    adjacent_nodes = {k:[vi for vi in v if k != vi] for k,v in nodes_new.items()}



    random.seed(2021)
    demand= {}
    for v in graph_input.nodes:
        demand[v] = random.randint(15,369)

    random.seed(2021)
    workload= {}
    for v in graph_input.nodes:
        workload[v] = random.randint(15,89)

    random.seed(2021)
    n_customers= {}
    for v in graph_input.nodes:
        n_customers[v] = random.randint(4,19)

    random.seed(2021)
    for v in centers_depots:
        demand[v] = 400
        workload[v] = 100
        n_customers[v] = 20
        for i in adjacent_nodes[v]:
            demand[i] = random.randint(370,400)
            workload[i] = random.randint(90,100)
            n_customers[i] = random.randint(15,20)

    random.seed(2021)
    distance= {}
    for e in graph_input.edges:
        distance[e] = random.randint(6,40)


    nx.set_node_attributes(graph_input, values = n_customers, name = "n_customers")
    nx.set_node_attributes(graph_input, values = demand, name = "demand")
    nx.set_node_attributes(graph_input, values = workload, name = "workload")
    nx.set_edge_attributes(graph_input, values = distance, name = "distance")
    
    
    shortest_paths_dict = get_furthest_nodes(graph_input)['node_shortest_path_dicts']
    graph_diameter = get_furthest_nodes(graph_input)['diameter']

    total_workload = 0 
    for v in graph_input.nodes:
        total_workload = total_workload + graph_input.nodes[v]['workload']
    average_workload = total_workload/len(centers_depots)

    total_customers = 0 
    for v in graph_input.nodes:
        total_customers = total_customers + graph_input.nodes[v]['n_customers']
    average_customers = total_customers/len(centers_depots)

    total_demand = 0 
    for v in graph_input.nodes:
        total_demand = total_demand + graph_input.nodes[v]['demand']
    average_demand = total_demand/len(centers_depots)



    selected_nodes = {}
    near_nodes = {}
    for k in centers_depots:
        selected_nodes[k] = []
        selected_nodes[k] = nx.ego_graph(graph_input,k, radius = 30, center=False, undirected=True, distance='distance')
        near_nodes[k] = list(selected_nodes[k].nodes())

#     for v in near_nodes:
#         print(list(any(v in val for val in near_nodes.values())))

    #Find the percentage of selected nodes from the graph
    num_nodes = 0
    for i in near_nodes:
        num_nodes = num_nodes+len(near_nodes[i])

    percentage_nodes = 1-(num_nodes/len(nodes))

    construction_time = time.time()

    #Create the initial districts by assigning the nodes in the neighborhood to depots
    district_customers = {}
    district_workload = {}
    district_demand = {}
    unassigned = graph_input.nodes
    neighborhood = {}
    district = {}
    rcl = {}
    i = 0
    while percentage_nodes*len(graph_input.nodes) <= len(unassigned):
        for k in centers_depots:
            district_customers[k]= 0
            district_workload[k] = 0
            district_demand[k] = 0
            neighborhood[k] = []
            neighborhood[k] = near_nodes[k]
            unassigned = unassigned-set(near_nodes[k])-set(centers_depots)
            district[k] = []
            district[k] = Union(district[k], neighborhood[k])
    #Find the total of each activity for each district
            for w in district[k]:
                district_customers[k] = district_customers[k] + graph_input.nodes[w]['n_customers']
                district_workload[k] = district_workload[k] + graph_input.nodes[w]['workload']
                district_demand[k] = district_demand[k] + graph_input.nodes[w]['demand']
                


    local_infeasible = 0

    for i in range(len(centers_depots)):
        local_infeasible = local_infeasible + ((1/average_customers)*max(district_customers[centers_depots[i]]-(1+delta)*average_customers,(1-delta)*average_customers-district_customers[centers_depots[i]],0))+\
            ((1/average_demand)*max(district_demand[centers_depots[i]]-(1+delta)*average_demand,(1-delta)*average_demand-district_demand[centers_depots[i]],0))+\
                ((1/average_workload)*max(district_workload[centers_depots[i]]-(1+delta)*average_workload,(1-delta)*average_workload-district_workload[centers_depots[i]],0))

    #Select a larger neighborhood for the depots
    larger_selected_nodes = {}
    larger_selected_nodes = {}
    for k in centers_depots:
        larger_selected_nodes[k] = []
        larger_selected_nodes[k] = nx.ego_graph(graph_input,k, radius = 100, center=False, undirected=True, distance='distance')
        larger_selected_nodes[k] = list(set(larger_selected_nodes[k].nodes())-set(district[k]))

    #Ensure that there is no overlap between the neighborhoods
    new_neighborhood = {}
    for k in centers_depots:
        new_neighborhood[k] = []
        for v in larger_selected_nodes[k]:
            x = list(any(v in val for val in new_neighborhood.values()))
            y = list(any(v in val for val in district.values()))
            if True not in x:
                if True not in y:             
                    new_neighborhood[k].append(v)



    #Find the infeasibility of each district
    infeasible = {}

    for k in district:
        infeasible[k] = {}
        for v in new_neighborhood[k]:
            infeasible[k][v] = (1/average_workload)*max(district_workload[k]+graph_input.nodes[v]['workload']-(1+delta)*average_workload,0)+\
                (1/average_customers)*max(district_customers[k]+graph_input.nodes[v]['n_customers']-(1+delta)*average_customers,0)+\
                    (1/average_demand)*max(district_demand[k]+graph_input.nodes[v]['demand']-(1+delta)*average_demand,0)

    obj_dispersion = max(shortest_paths_dict[x][y] for i in district for x in district[i] for y in district[i])
    frac_diameter = (1/graph_diameter)
    #Find the average dispersion of each district
    dispersion = {}
    for k in district:
        dispersion[k] = {}
        for v in new_neighborhood[k]:
            dispersion[k][v] = frac_diameter*max(obj_dispersion, max(shortest_paths_dict[x][y] for x in Union(district[k],[v]) for y in Union(district[k],[v])))

    phi = {}

    for k in district:
        phi[k] = {}
        for v in new_neighborhood[k]:
            phi[k][v] = llambda*dispersion[k][v]+(1-llambda)*infeasible[k][v]



    phi_min = {}
    for k in district:
        phi_min[k] = min(phi[k].values())

    phi_max = {}
    for k in district:
        phi_max[k] = max(phi[k].values())



    open_district = {}
    for k in district:
        open_district[k] = True

    #Create the restricted candidate list

    rcl = {}

    for k in district:
        rcl[k] = []
        if open_district[k] == True:
            for h in new_neighborhood[k]:
                if phi[k][h] <= phi_min[k]+rcl_parameter*(phi_max[k]-phi_min[k]):
                    rcl[k].append(h)

    x = 0
    r = 0
    i=0
    viable = False
    OR_OPEN = True
    RCL_EMPTY = True
    NOT_OPEN = False
    UNASSIGNED_REPEAT = False
    final_depot = False
    unassigned_length = len(unassigned)
    unassigned_previous = 0
    while ((len(unassigned) >0) and not NOT_OPEN and not UNASSIGNED_REPEAT):
        if unassigned_length == unassigned_previous:
            UNASSIGNED_REPEAT = True
#         print(unassigned_length)
        unassigned_previous = len(unassigned)
        for k in centers_depots:
            # print("First chosen depot k is")
            # print(k)
            # print("Length of RCL is")
            # print(len(rcl[k]))
            # print("The district is ")
            # print(open_district[k])

            if (len(rcl[k]) == 0):
                #print("RCL EMPTY: Going to next iteration.")
                continue

            if open_district[k]:
                for deleted in rcl[k]:
                    for i in district[k]:
                        if deleted in adjacent_nodes[i]:                        
                            if deleted in rcl[k]:
                                # print("Chosen RCL element is")
                                # print(deleted)
                                rcl[k].remove(deleted)            
                                district[k].append(deleted)
                                district_customers[k] = district_customers[k] + graph_input.nodes[deleted]['n_customers']
                                district_demand[k] = district_demand[k] + graph_input.nodes[deleted]['demand'] 
                                district_workload[k] = district_workload[k] + graph_input.nodes[deleted]['workload'] 
                                #unassigned_previous = len(unassigned)
                                if deleted in unassigned:
                                    unassigned.remove(deleted)
                                    unassigned_length = len(unassigned)
                                if (len(new_neighborhood[k]) <= 0) or (district_customers[k] >= average_customers+delta)\
                                        or (district_demand[k] >= average_demand+delta) or (district_workload[k] >= average_workload+delta):
                                    open_district[k] = False
            else:
                #print("District closed: Going to next iteration.")
                continue


        # if unassigned_length == unassigned_previous:
        #     UNASSIGNED_REPEAT = True
        # print(unassigned_length)
        # unassigned_previous = len(unassigned)




        if True not in open_district.values():
            NOT_OPEN = True

    #         RCL_EMPTY = False
    #         while len(rcl[depots[r]])<=0 and r<=len(depots):
    #             r = r+1
    #         if r <len(depots):
    #             RCL_EMPTY = True

#     for k in centers_depots:
#         for i in district[k]:
#             print(list(any(i in val for val in district.values())))




    a =  0
    unassigned = list(unassigned)
    for k in centers_depots:
        for x in district[k]:
            for v in unassigned:
                if v in adjacent_nodes[x]:
                    if open_district[k] == True:
                        unique_pls = list(any(v in val for val in district.values()))
                        if True not in unique_pls:
                            district[k].append(v)
                            unassigned.remove(v)
                            district_customers[k] = district_customers[k] + graph_input.nodes[v]['n_customers']
                            district_demand[k] = district_demand[k] + graph_input.nodes[v]['demand'] 
                            district_workload[k] = district_workload[k] + graph_input.nodes[v]['workload'] 
                            if (district_customers[k] >= average_customers+delta) or (district_demand[k] >= average_demand+delta) \
                                or (district_workload[k] >= average_workload+delta):
                                open_district[k] = False

                                

    
    a =  0
    unassigned = list(unassigned)
    for k in centers_depots:
        for x in district[k]:
            for v in unassigned:
                if v in adjacent_nodes[x]:
                    unique_pls = list(any(v in val for val in district.values()))
                    if True not in unique_pls:
                        district[k].append(v)
                        unassigned.remove(v)
                        district_customers[k] = district_customers[k] + graph_input.nodes[v]['n_customers']
                        district_demand[k] = district_demand[k] + graph_input.nodes[v]['demand'] 
                        district_workload[k] = district_workload[k] + graph_input.nodes[v]['workload'] 
                        if (district_customers[k] >= average_customers+delta) or (district_demand[k] >= average_demand+delta) \
                            or (district_workload[k] >= average_workload+delta):
                            open_district[k] = False

    unassigned = list(unassigned)
    #i = depots[0]
    #a = (a+1) % len(depots)
    for k in centers_depots:
        for x in district[k]:
            for v in unassigned:
                if v in adjacent_nodes[x]:
                    unique_pls = list(any(v in val for val in district.values()))
                    if True not in unique_pls:
                        district[k].append(v)
                        unassigned.remove(v)
                        district_customers[k] = district_customers[k] + graph_input.nodes[v]['n_customers']
                        district_demand[k] = district_demand[k] + graph_input.nodes[v]['demand'] 
                        district_workload[k] = district_workload[k] + graph_input.nodes[v]['workload'] 
                        if (district_customers[k] >= average_customers+delta) or (district_demand[k] >= average_demand+delta) \
                            or (district_workload[k] >= average_workload+delta):
                            open_district[k] = False

    districts_keys = list(district.keys())
    colorss = ["lightcoral","sandybrown","darkorange","lawngreen","green","aqua","steelblue","violet","purple","maroon"]

    color_map = {}
    for node in list(graph_input.nodes):
        color_map[node] = "blue"
        for k in range(len(districts_keys)):
            if node in district[districts_keys[k]]:
                color_map[node] = colorss[k]
    

    color_map = list(color_map.values())

#     plt.figure(3,figsize=(12,12))
#     nx.draw(graph_input,node_color=color_map, pos=grid_pos,with_labels = True)
#     plt.show()

    local_infeasible = 0

    for i in range(len(centers_depots)):
        local_infeasible = local_infeasible + ((1/average_customers)*max(district_customers[centers_depots[i]]-(1+delta)*average_customers,(1-delta)*average_customers-district_customers[centers_depots[i]],0))+\
            ((1/average_demand)*max(district_demand[centers_depots[i]]-(1+delta)*average_demand,(1-delta)*average_demand-district_demand[centers_depots[i]],0))+\
                ((1/average_workload)*max(district_workload[centers_depots[i]]-(1+delta)*average_workload,(1-delta)*average_workload-district_workload[centers_depots[i]],0))

    #print(local_infeasible)
    construction_obj = max(shortest_paths_dict[x][y] for i in district for x in district[i] for y in district[i])
    
    return district, centers_depots, combinations, adjacent_nodes, average_customers, average_demand,average_workload,shortest_paths_dict, construction_obj,local_infeasible

# %%
def construction_grasp(delta, rcl_parameter,llambda,graph_input):
    #Choosing centers

#     locations = np.array(coords)

#     centroids = plus_plus(locations, 2)

#     centroids = centroids.tolist()

#     centroids_tuple = []
#     for i in centroids:
#         centroids_tuple.append(tuple((i)))

#     centers_depots = []
#     for i in centroids_tuple:
#         for key, value in grid_pos.items():
#             if i == value:
#                 centers_depots.append(key)

    centers_depots = [0,20,24]
                
    #Initialize randomized activities
    combinations = list(itertools.combinations(centers_depots, 3))



    #Calculate the average for each activity
    adjacent = {}
    for i in graph_input.nodes():
            adjacent[i] = []
    for e in graph_input.edges():
        adjacent[e[0]].append(e)
        adjacent[e[1]].append(e)

    #Define adjacent nodes for each node

    adjacent_nodes = {}
    nodes_new = {}
    for i in adjacent:
        adjacent_nodes[i] = []
        for e in range(len(adjacent[i])):
            adjacent_nodes[i].append(adjacent[i][e][0])
            adjacent_nodes[i].append(adjacent[i][e][1])
    for i in adjacent_nodes:
        nodes_new[i] = list(set(adjacent_nodes[i]))
    adjacent_nodes = {k:[vi for vi in v if k != vi] for k,v in nodes_new.items()}



    random.seed(2021)
    demand= {}
    for v in graph_input.nodes:
        demand[v] = 1

    random.seed(2021)
    workload= {}
    for v in graph_input.nodes:
        workload[v] = 1

    random.seed(2021)
    n_customers= {}
    for v in graph_input.nodes:
        n_customers[v] = 1

#     random.seed(2021)
#     for v in centers_depots:
#         demand[v] = 400
#         workload[v] = 100
#         n_customers[v] = 20
#         for i in adjacent_nodes[v]:
#             demand[i] = random.randint(370,400)
#             workload[i] = random.randint(90,100)
#             n_customers[i] = random.randint(15,20)

#     random.seed(2021)
    distance= {}
    for e in graph_input.edges:
        distance[e] = 1


    nx.set_node_attributes(graph_input, values = n_customers, name = "n_customers")
    nx.set_node_attributes(graph_input, values = demand, name = "demand")
    nx.set_node_attributes(graph_input, values = workload, name = "workload")
    nx.set_edge_attributes(graph_input, values = distance, name = "distance")
    
    
    shortest_paths_dict = get_furthest_nodes(graph_input)['node_shortest_path_dicts']
    graph_diameter = get_furthest_nodes(graph_input)['diameter']

    total_workload = 0 
    for v in graph_input.nodes:
        total_workload = total_workload + graph_input.nodes[v]['workload']
    average_workload = total_workload/len(centers_depots)

    total_customers = 0 
    for v in graph_input.nodes:
        total_customers = total_customers + graph_input.nodes[v]['n_customers']
    average_customers = total_customers/len(centers_depots)

    total_demand = 0 
    for v in graph_input.nodes:
        total_demand = total_demand + graph_input.nodes[v]['demand']
    average_demand = total_demand/len(centers_depots)



    selected_nodes = {}
    near_nodes = {}
    for k in centers_depots:
        selected_nodes[k] = []
        selected_nodes[k] = nx.ego_graph(graph_input,k, radius = 1, center=False, undirected=True, distance='distance')
        near_nodes[k] = list(selected_nodes[k].nodes())

#     for v in near_nodes:
#         print(list(any(v in val for val in near_nodes.values())))

    #Find the percentage of selected nodes from the graph
    num_nodes = 0
    for i in near_nodes:
        num_nodes = num_nodes+len(near_nodes[i])

    percentage_nodes = 1-(num_nodes/len(nodes))

    construction_time = time.time()

    #Create the initial districts by assigning the nodes in the neighborhood to depots
    district_customers = {}
    district_workload = {}
    district_demand = {}
    unassigned = set(graph_input.nodes) - set(centers_depots)
    neighborhood = {}
    district = {}

    rcl = {}
    i = 0
    while 0.7*len(graph_input.nodes) <= len(unassigned):
        print("In while loop")
#         district[0] = unassigned

        for k in centers_depots:
            district_customers[k]= 0
            district_workload[k] = 0
            district_demand[k] = 0
            neighborhood[k] = []
            neighborhood[k] = near_nodes[k]
            unassigned = unassigned-set(near_nodes[k])-set(centers_depots)
            district[k] = []
            district[k] = Union(district[k], neighborhood[k])
#Find the total of each activity for each district
        for w in district[k]:
            district_customers[k] = district_customers[k] + graph_input.nodes[w]['n_customers']
            district_workload[k] = district_workload[k] + graph_input.nodes[w]['workload']
            district_demand[k] = district_demand[k] + graph_input.nodes[w]['demand']
        print(district)
        print(len(unassigned))
                
            
    


    local_infeasible = 0

    for i in range(len(centers_depots)):
        local_infeasible = local_infeasible + ((1/average_customers)*max(district_customers[centers_depots[i]]-(1+delta)*average_customers,(1-delta)*average_customers-district_customers[centers_depots[i]],0))+\
            ((1/average_demand)*max(district_demand[centers_depots[i]]-(1+delta)*average_demand,(1-delta)*average_demand-district_demand[centers_depots[i]],0))+\
                ((1/average_workload)*max(district_workload[centers_depots[i]]-(1+delta)*average_workload,(1-delta)*average_workload-district_workload[centers_depots[i]],0))

    #Select a larger neighborhood for the depots
    larger_selected_nodes = {}
    larger_selected_nodes = {}
    for k in centers_depots:
        larger_selected_nodes[k] = []
        larger_selected_nodes[k] = nx.ego_graph(graph_input,k, radius = 4, center=False, undirected=True, distance='distance')
        larger_selected_nodes[k] = list(set(larger_selected_nodes[k].nodes())-set(district[k]))

    #Ensure that there is no overlap between the neighborhoods
    new_neighborhood = {}
    for k in centers_depots:
        new_neighborhood[k] = []
        for v in larger_selected_nodes[k]:
            x = list(any(v in val for val in new_neighborhood.values()))
            y = list(any(v in val for val in district.values()))
            if True not in x:
                if True not in y:             
                    new_neighborhood[k].append(v)



    #Find the infeasibility of each district
    infeasible = {}

    for k in district:
        infeasible[k] = {}
        for v in new_neighborhood[k]:
            infeasible[k][v] = (1/average_workload)*max(district_workload[k]+graph_input.nodes[v]['workload']-(1+delta)*average_workload,0)+\
                (1/average_customers)*max(district_customers[k]+graph_input.nodes[v]['n_customers']-(1+delta)*average_customers,0)+\
                    (1/average_demand)*max(district_demand[k]+graph_input.nodes[v]['demand']-(1+delta)*average_demand,0)

    obj_dispersion = max(shortest_paths_dict[x][y] for i in district for x in district[i] for y in district[i])
    frac_diameter = (1/graph_diameter)
    #Find the average dispersion of each district
    dispersion = {}
    for k in district:
        dispersion[k] = {}
        for v in new_neighborhood[k]:
            dispersion[k][v] = frac_diameter*max(obj_dispersion, max(shortest_paths_dict[x][y] for x in Union(district[k],[v]) for y in Union(district[k],[v])))

    phi = {}

    for k in district:
        phi[k] = {}
        for v in new_neighborhood[k]:
            phi[k][v] = llambda*dispersion[k][v]+(1-llambda)*infeasible[k][v]



    phi_min = {}
    for k in district:
        phi_min[k] = min(phi[k].values())

    phi_max = {}
    for k in district:
        phi_max[k] = max(phi[k].values())



    open_district = {}
    for k in district:
        open_district[k] = True

    #Create the restricted candidate list

    rcl = {}

    for k in district:
        rcl[k] = []
        if open_district[k] == True:
            for h in new_neighborhood[k]:
                if phi[k][h] <= phi_min[k]+rcl_parameter*(phi_max[k]-phi_min[k]):
                    rcl[k].append(h)

    x = 0
    r = 0
    i=0
    viable = False
    OR_OPEN = True
    RCL_EMPTY = True
    NOT_OPEN = False
    UNASSIGNED_REPEAT = False
    final_depot = False
    unassigned_length = len(unassigned)
    unassigned_previous = 0
    while ((len(unassigned) >0) and not NOT_OPEN and not UNASSIGNED_REPEAT):
        if unassigned_length == unassigned_previous:
            UNASSIGNED_REPEAT = True
#         print(unassigned_length)
        unassigned_previous = len(unassigned)
        for k in centers_depots:
            # print("First chosen depot k is")
            # print(k)
            # print("Length of RCL is")
            # print(len(rcl[k]))
            # print("The district is ")
            # print(open_district[k])

            if (len(rcl[k]) == 0):
                #print("RCL EMPTY: Going to next iteration.")
                continue

            if open_district[k]:
                for deleted in rcl[k]:
                    for i in district[k]:
                        if deleted in adjacent_nodes[i]:                        
                            if deleted in rcl[k]:
                                # print("Chosen RCL element is")
                                # print(deleted)
                                rcl[k].remove(deleted)            
                                district[k].append(deleted)
                                district_customers[k] = district_customers[k] + graph_input.nodes[deleted]['n_customers']
                                district_demand[k] = district_demand[k] + graph_input.nodes[deleted]['demand'] 
                                district_workload[k] = district_workload[k] + graph_input.nodes[deleted]['workload'] 
                                #unassigned_previous = len(unassigned)
                                if deleted in unassigned:
                                    unassigned.remove(deleted)
                                    unassigned_length = len(unassigned)
                                if (len(new_neighborhood[k]) <= 0) or (district_customers[k] >= average_customers+delta)\
                                        or (district_demand[k] >= average_demand+delta) or (district_workload[k] >= average_workload+delta):
                                    open_district[k] = False
            else:
                #print("District closed: Going to next iteration.")
                continue


        # if unassigned_length == unassigned_previous:
        #     UNASSIGNED_REPEAT = True
        # print(unassigned_length)
        # unassigned_previous = len(unassigned)




        if True not in open_district.values():
            NOT_OPEN = True

    #         RCL_EMPTY = False
    #         while len(rcl[depots[r]])<=0 and r<=len(depots):
    #             r = r+1
    #         if r <len(depots):
    #             RCL_EMPTY = True

#     for k in centers_depots:
#         for i in district[k]:
#             print(list(any(i in val for val in district.values())))




    a =  0
    unassigned = list(unassigned)
    for k in centers_depots:
        for x in district[k]:
            for v in unassigned:
                if v in adjacent_nodes[x]:
                    if open_district[k] == True:
                        unique_pls = list(any(v in val for val in district.values()))
                        if True not in unique_pls:
                            district[k].append(v)
                            unassigned.remove(v)
                            district_customers[k] = district_customers[k] + graph_input.nodes[v]['n_customers']
                            district_demand[k] = district_demand[k] + graph_input.nodes[v]['demand'] 
                            district_workload[k] = district_workload[k] + graph_input.nodes[v]['workload'] 
                            if (district_customers[k] >= average_customers+delta) or (district_demand[k] >= average_demand+delta) \
                                or (district_workload[k] >= average_workload+delta):
                                open_district[k] = False

                                

    
    a =  0
    unassigned = list(unassigned)
    for k in centers_depots:
        for x in district[k]:
            for v in unassigned:
                if v in adjacent_nodes[x]:
                    unique_pls = list(any(v in val for val in district.values()))
                    if True not in unique_pls:
                        district[k].append(v)
                        unassigned.remove(v)
                        district_customers[k] = district_customers[k] + graph_input.nodes[v]['n_customers']
                        district_demand[k] = district_demand[k] + graph_input.nodes[v]['demand'] 
                        district_workload[k] = district_workload[k] + graph_input.nodes[v]['workload'] 
                        if (district_customers[k] >= average_customers+delta) or (district_demand[k] >= average_demand+delta) \
                            or (district_workload[k] >= average_workload+delta):
                            open_district[k] = False

    unassigned = list(unassigned)
    #i = depots[0]
    #a = (a+1) % len(depots)
    for k in centers_depots:
        for x in district[k]:
            for v in unassigned:
                if v in adjacent_nodes[x]:
                    unique_pls = list(any(v in val for val in district.values()))
                    if True not in unique_pls:
                        district[k].append(v)
                        unassigned.remove(v)
                        district_customers[k] = district_customers[k] + graph_input.nodes[v]['n_customers']
                        district_demand[k] = district_demand[k] + graph_input.nodes[v]['demand'] 
                        district_workload[k] = district_workload[k] + graph_input.nodes[v]['workload'] 
                        if (district_customers[k] >= average_customers+delta) or (district_demand[k] >= average_demand+delta) \
                            or (district_workload[k] >= average_workload+delta):
                            open_district[k] = False

#     districts_keys = list(district.keys())
#     colorss = ["lightcoral","sandybrown","darkorange","lawngreen","green","aqua","steelblue","violet","purple","maroon"]

#     color_map = {}
#     for node in list(graph_input.nodes):
#         color_map[node] = "blue"
#         for k in range(len(districts_keys)):
#             if node in district[districts_keys[k]]:
#                 color_map[node] = colorss[k]
    

#     color_map = list(color_map.values())

#     plt.figure(3,figsize=(12,12))
#     nx.draw(graph_input,node_color=color_map, pos=grid_pos,with_labels = True)
#     plt.show()

    local_infeasible = 0

    for i in range(len(centers_depots)):
        local_infeasible = local_infeasible + ((1/average_customers)*max(district_customers[centers_depots[i]]-(1+delta)*average_customers,(1-delta)*average_customers-district_customers[centers_depots[i]],0))+\
            ((1/average_demand)*max(district_demand[centers_depots[i]]-(1+delta)*average_demand,(1-delta)*average_demand-district_demand[centers_depots[i]],0))+\
                ((1/average_workload)*max(district_workload[centers_depots[i]]-(1+delta)*average_workload,(1-delta)*average_workload-district_workload[centers_depots[i]],0))

    #print(local_infeasible)
    construction_obj = max(shortest_paths_dict[x][y] for i in district for x in district[i]+[i] for y in district[i]+[i])
    
    return district, centers_depots, combinations, adjacent_nodes, average_customers, average_demand,average_workload,shortest_paths_dict, construction_obj,local_infeasible

# %%
district, centers_depots, combinations, adjacent_nodes, average_customers, average_demand,average_workload,shortest_paths_dict, construction_obj,construction_infeasible = construction_grasp(0.05, 0.3,0.7,G1)
for i in district:
    print(len(district[i]))
print(construction_infeasible)
print(construction_obj)
# Out:
# 75
# 73
# 45
# 48
# 56
# 11
# 9
# 68
# 53
# 52
# 7.970830773740374
# 565

# %%
input_one = district, centers_depots, combinations, adjacent_nodes, average_customers, average_demand,average_workload,shortest_paths_dict, construction_obj,construction_infeasible

# %%
input_two = district, centers_depots, combinations, adjacent_nodes, average_customers, average_demand,average_workload,shortest_paths_dict, construction_obj,construction_infeasible

# %%
input_three = district, centers_depots, combinations, adjacent_nodes, average_customers, average_demand,average_workload,shortest_paths_dict, construction_obj,construction_infeasible

# %%
input_one_graphthree = district, centers_depots, combinations, adjacent_nodes, average_customers, average_demand,average_workload,shortest_paths_dict, construction_obj,construction_infeasible

# %%
input_two_graphthree = district, centers_depots, combinations, adjacent_nodes, average_customers, average_demand,average_workload,shortest_paths_dict, construction_obj,construction_infeasible

# %%
input_three_graphthree = district, centers_depots, combinations, adjacent_nodes, average_customers, average_demand,average_workload,shortest_paths_dict, construction_obj,construction_infeasible

# %%
for k in centers_depots:
    for i in district[k]:
        print(list(any(i in val for val in district.values())))
# Out:
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]

# %%
centers_depots
# Out:
# [721, 176, 646, 544, 77, 60, 557, 657, 0, 277]

# %%
input_one_graphtwo = district, centers_depots, combinations, adjacent_nodes, average_customers, average_demand,average_workload,shortest_paths_dict, construction_obj,construction_infeasible

# %%
input_two_graphtwo = district, centers_depots, combinations, adjacent_nodes, average_customers, average_demand,average_workload,shortest_paths_dict, construction_obj,construction_infeasible

# %%
input_three_graphtwo = district, centers_depots, combinations, adjacent_nodes, average_customers, average_demand,average_workload,shortest_paths_dict, construction_obj,construction_infeasible

# %%
districts_keys = list(input_one[0].keys())
colorss = ["lightcoral","sandybrown","darkorange","lawngreen","green","aqua","steelblue","violet","purple","maroon"]

color_map = {}
for node in list(G1.nodes):
    color_map[node] = "blue"
    for k in range(len(districts_keys)):
        if node in input_one[0][districts_keys[k]]:
            color_map[node] = colorss[k]

color_map = list(color_map.values())

plt.figure(3,figsize=(12,12))
nx.draw(G1,node_color=color_map, pos=grid_pos,with_labels = True)
plt.show()

# %%
#31/01/2022

#Without Updating Objective Function and Ordered V.2

#Check all nodes and pick the best
    
#Create a function that calculates the linear combination of infeasibility and dispersion for two selected districts.
def localsearch_node_best_improvement(district,centers_depots,combinations,adjacent_nodes,average_customers, average_demand,average_workload,shortest_paths_dict,llambda,delta,graph_input):    
   
    #Save value of best solution for comparisons. Onlly calculate the new one. Update when you find a better solution.
    #Update membership of each district. 
    
    
    def decision(x,y):

        y_customers = {}
        y_demand = {}
        y_workload = {}

        x_customers = {}
        x_demand = {}
        x_workload = {}

        for k in centers_depots:
            y_customers[k] = 0
            y_demand[k] = 0
            y_workload[k] = 0
            x_customers[k] = 0
            x_demand[k] = 0
            x_workload[k] = 0

    #Calculate the total for each  activity measure for each district allocation
        for k in centers_depots:
            for w in y[k]:
                y_customers[k] = y_customers[k] + graph_input.nodes[w]['n_customers']
                y_workload[k] = y_workload[k] + graph_input.nodes[w]['workload']
                y_demand[k] = y_demand[k] + graph_input.nodes[w]['demand']
            for w in x[k]:
                x_customers[k] = x_customers[k] + graph_input.nodes[w]['n_customers']
                x_workload[k] = x_workload[k] + graph_input.nodes[w]['workload']
                x_demand[k] = x_demand[k] + graph_input.nodes[w]['demand']






        weight_district_temp_f = (max(shortest_paths_dict[a][b] for i in y for a in y[i] for b in y[i]))
        #weight_district_temp_f = llambda*(max(get_furthest_nodes(graph_input.subgraph(y[centers_depots[i]]))['diameter'] for i in range(len(centers_depots))))

        weight_district_temp_g = 0
        for i in range(len(centers_depots)):

            ga1_temp = ((1/average_customers)*max(y_customers[centers_depots[i]]-(1+delta)*average_customers,(1-delta)*average_customers-y_customers[centers_depots[i]],0))
            ga2_temp = ((1/average_demand)*max(y_demand[centers_depots[i]]-(1+delta)*average_demand,(1-delta)*average_demand-y_demand[centers_depots[i]],0))
            ga3_temp = ((1/average_workload)*max(y_workload[centers_depots[i]]-(1+delta)*average_workload,(1-delta)*average_workload-y_workload[centers_depots[i]],0))

            weight_district_temp_g = weight_district_temp_g +(ga1_temp+ga2_temp+ga3_temp)

        weight_district_temp = llambda*weight_district_temp_f + (1-llambda)*weight_district_temp_g





        weight_district_best_f = (max(shortest_paths_dict[a][b] for i in x for a in x[i] for b in x[i]))
        weight_district_best_g = 0
        for i in range(len(centers_depots)):
            
            ga1_best = ((1/average_customers)*max(x_customers[centers_depots[i]]-(1+delta)*average_customers,(1-delta)*average_customers-x_customers[centers_depots[i]],0))
            ga2_best = ((1/average_demand)*max(x_demand[centers_depots[i]]-(1+delta)*average_demand,(1-delta)*average_demand-x_demand[centers_depots[i]],0))
            ga3_best = ((1/average_workload)*max(x_workload[centers_depots[i]]-(1+delta)*average_workload,(1-delta)*average_workload-x_workload[centers_depots[i]],0))

            weight_district_best_g = weight_district_best_g + (ga1_best+ga2_best+ga3_best)



        weight_district_best = llambda*weight_district_best_f + (1-llambda)*weight_district_best_g

    #Return True if the first district allocation is better

        if(weight_district_temp<weight_district_best):

            return True
        else:

            return False

    
    def merit_function(x):

        x_customers = {}
        x_demand = {}
        x_workload = {}

        for k in centers_depots:
            x_customers[k] = 0
            x_demand[k] = 0
            x_workload[k] = 0

    #Calculate the total for each  activity measure for each district allocation
        for k in centers_depots:
            for w in x[k]:
                x_customers[k] = x_customers[k] + graph_input.nodes[w]['n_customers']
                x_workload[k] = x_workload[k] + graph_input.nodes[w]['workload']
                x_demand[k] = x_demand[k] + graph_input.nodes[w]['demand']

        weight_district_best_f = (max(shortest_paths_dict[a][b] for i in x for a in x[i]+[i] for b in x[i]+[i]))

        weight_district_best_g = 0
        for i in range(len(centers_depots)):

            ga1_best = ((1/average_customers)*max(x_customers[centers_depots[i]]-(1+delta)*average_customers,(1-delta)*average_customers-x_customers[centers_depots[i]],0))
            ga2_best = ((1/average_demand)*max(x_demand[centers_depots[i]]-(1+delta)*average_demand,(1-delta)*average_demand-x_demand[centers_depots[i]],0))
            ga3_best = ((1/average_workload)*max(x_workload[centers_depots[i]]-(1+delta)*average_workload,(1-delta)*average_workload-x_workload[centers_depots[i]],0))

            weight_district_best_g = weight_district_best_g + (ga1_best+ga2_best+ga3_best)

        weight_district_best = llambda*weight_district_best_f + (1-llambda)*weight_district_best_g

    #Return value of merit function

        return weight_district_best
        
        
        
        
    def update_merit_function(input_solution,k,l,bu):
        x= cp.deepcopy(input_solution)
        x[l].remove(bu)
        x[k].append(bu)

        x_customers = {}
        x_demand = {}
        x_workload = {}

        for k in centers_depots:
            x_customers[k] = 0
            x_demand[k] = 0
            x_workload[k] = 0

        #Calculate the total for each  activity measure for each district allocation
        for k in centers_depots:
            for w in x[k]:
                x_customers[k] = x_customers[k] + graph_input.nodes[w]['n_customers']
                x_workload[k] = x_workload[k] + graph_input.nodes[w]['workload']
                x_demand[k] = x_demand[k] + graph_input.nodes[w]['demand']

        solution_infeasibility = 0
        for i in range(len(centers_depots)):

            ga1_best = ((1/average_customers)*max(x_customers[centers_depots[i]]-(1+delta)*average_customers,(1-delta)*average_customers-x_customers[centers_depots[i]],0))
            ga2_best = ((1/average_demand)*max(x_demand[centers_depots[i]]-(1+delta)*average_demand,(1-delta)*average_demand-x_demand[centers_depots[i]],0))
            ga3_best = ((1/average_workload)*max(x_workload[centers_depots[i]]-(1+delta)*average_workload,(1-delta)*average_workload-x_workload[centers_depots[i]],0))

            solution_infeasibility = solution_infeasibility + (ga1_best+ga2_best+ga3_best)
        

        solution_objective = (max(shortest_paths_dict[a][b] for i in x for a in x[i]+[i] for b in x[i]+[i]))


        weight_district_best = llambda*solution_objective + (1-llambda)*solution_infeasibility

        return weight_district_best
    
    
    district_trial2 = {}
    best_sol = {}

    
    #Copy the current district allocation
    for i in range(len(centers_depots)):
        district_trial2[centers_depots[i]] = district[centers_depots[i]][:]

    for i in range(len(centers_depots)):
        best_sol[centers_depots[i]] = district[centers_depots[i]][:]
        
    node_district_matching = {}
    for k in district:
        for i in district[k]:
            node_district_matching[i] = k


     
    moves = {}
    for depots in centers_depots:
        moves[depots] = []
        for nodes in node_district_matching:
            if node_district_matching[nodes] != depots:
                moves[depots].append(nodes)
#     print(moves)

    depo_choices = {}
    for k in centers_depots:
        depo_choices[k] = [item for item in combinations
                if item[0] == k or item[1] == k]


    choose = random.choice(range(len(centers_depots)))

    k = centers_depots[choose]
    nmoves = 0
    p = len(centers_depots)
    local_optima = False

    number_of_moves = 0
    move_index = 0
    
            
    current_best_objective = merit_function(district)

    current_best_solution = cp.deepcopy(district)

    while(nmoves<1000 and local_optima==False):
        
#         print("Repeating the for loop again")
#         print("The current best objective is",current_best_objective)
        improvement = False
        for k in centers_depots:
#             print("Moving to next center",k)
            improvement = False
            for basic_unit in moves[k]:
                if nx.has_path(graph_input.subgraph(current_best_solution[k]+[k,basic_unit]),k,basic_unit) == True:
 
                    new_objective = update_merit_function(current_best_solution,k,node_district_matching[basic_unit],basic_unit)

                    if new_objective < current_best_objective:
    #                     print(k)
#                         print("Better Objective found")
                        best_basic_unit = basic_unit
#                         print(best_basic_unit)
                        current_best_objective = new_objective
                        improvement = True
            
            if improvement == True:
                current_best_solution[k].append(best_basic_unit)
                current_best_solution[node_district_matching[best_basic_unit]].remove(best_basic_unit)
#                 print("Succeeded in improving", current_best_objective)
#                 print("The best basic unit is", best_basic_unit)
                node_district_matching[best_basic_unit] = k
                moves[k].remove(best_basic_unit)
                moves[node_district_matching[best_basic_unit]].append(best_basic_unit)
                   


#             moves = {}
#             for depotss in centers_depots:
#                 moves[depotss] = []
#                 for nodes in node_district_matching:
#                     if node_district_matching[nodes] != depotss:
#                         moves[depotss].append(nodes)

        
        
        if improvement == True:    
            nmoves = nmoves+1
            local_optima = False
        else:
            local_optima = True
            print("Local Optimum Reached")
            
            
            
    best_obj = max(shortest_paths_dict[a][b] for i in current_best_solution for a in current_best_solution[i]+[i] for b in current_best_solution[i]+[i])
    
    best_sol_customers = {}
    best_sol_workload = {}
    best_sol_demand = {}
    
    for k in centers_depots:
        best_sol_customers[k]=0
        best_sol_demand[k]=0
        best_sol_workload[k]=0
        
    for k in centers_depots:
        for w in current_best_solution[k]:
            best_sol_customers[k] = best_sol_customers[k] + graph_input.nodes[w]['n_customers']
            best_sol_workload[k] = best_sol_workload[k] + graph_input.nodes[w]['workload']
            best_sol_demand[k] = best_sol_demand[k] + graph_input.nodes[w]['demand']
    
    local_infeasible = 0
    
    for i in range(len(centers_depots)):
        local_infeasible = local_infeasible + ((1/average_customers)*max(best_sol_customers[centers_depots[i]]-(1+delta)*average_customers,(1-delta)*average_customers-best_sol_customers[centers_depots[i]],0))+\
            ((1/average_demand)*max(best_sol_demand[centers_depots[i]]-(1+delta)*average_demand,(1-delta)*average_demand-best_sol_demand[centers_depots[i]],0))+\
                ((1/average_workload)*max(best_sol_workload[centers_depots[i]]-(1+delta)*average_workload,(1-delta)*average_workload-best_sol_workload[centers_depots[i]],0))

    #print(local_infeasible)
    
    return best_obj, local_infeasible, current_best_solution

# %%
#06/02/2022

#Without Updating Objective Function and Ordered V.2

#First improvement Local search
    
#Create a function that calculates the linear combination of infeasibility and dispersion for two selected districts.
def localsearch_node_first_improvement(district,centers_depots,combinations,adjacent_nodes,average_customers, average_demand,average_workload,shortest_paths_dict,llambda,delta,graph_input):    
   
    #Save value of best solution for comparisons. Onlly calculate the new one. Update when you find a better solution.
    #Update membership of each district. 
    
    
    def decision(x,y):

        y_customers = {}
        y_demand = {}
        y_workload = {}

        x_customers = {}
        x_demand = {}
        x_workload = {}

        for k in centers_depots:
            y_customers[k] = 0
            y_demand[k] = 0
            y_workload[k] = 0
            x_customers[k] = 0
            x_demand[k] = 0
            x_workload[k] = 0

    #Calculate the total for each  activity measure for each district allocation
        for k in centers_depots:
            for w in y[k]:
                y_customers[k] = y_customers[k] + graph_input.nodes[w]['n_customers']
                y_workload[k] = y_workload[k] + graph_input.nodes[w]['workload']
                y_demand[k] = y_demand[k] + graph_input.nodes[w]['demand']
            for w in x[k]:
                x_customers[k] = x_customers[k] + graph_input.nodes[w]['n_customers']
                x_workload[k] = x_workload[k] + graph_input.nodes[w]['workload']
                x_demand[k] = x_demand[k] + graph_input.nodes[w]['demand']






        weight_district_temp_f = (max(shortest_paths_dict[a][b] for i in y for a in y[i] for b in y[i]))
        #weight_district_temp_f = llambda*(max(get_furthest_nodes(graph_input.subgraph(y[centers_depots[i]]))['diameter'] for i in range(len(centers_depots))))

        weight_district_temp_g = 0
        for i in range(len(centers_depots)):

            ga1_temp = ((1/average_customers)*max(y_customers[centers_depots[i]]-(1+delta)*average_customers,(1-delta)*average_customers-y_customers[centers_depots[i]],0))
            ga2_temp = ((1/average_demand)*max(y_demand[centers_depots[i]]-(1+delta)*average_demand,(1-delta)*average_demand-y_demand[centers_depots[i]],0))
            ga3_temp = ((1/average_workload)*max(y_workload[centers_depots[i]]-(1+delta)*average_workload,(1-delta)*average_workload-y_workload[centers_depots[i]],0))

            weight_district_temp_g = weight_district_temp_g +(ga1_temp+ga2_temp+ga3_temp)

        weight_district_temp = llambda*weight_district_temp_f + (1-llambda)*weight_district_temp_g





        weight_district_best_f = (max(shortest_paths_dict[a][b] for i in x for a in x[i] for b in x[i]))
        weight_district_best_g = 0
        for i in range(len(centers_depots)):
            
            ga1_best = ((1/average_customers)*max(x_customers[centers_depots[i]]-(1+delta)*average_customers,(1-delta)*average_customers-x_customers[centers_depots[i]],0))
            ga2_best = ((1/average_demand)*max(x_demand[centers_depots[i]]-(1+delta)*average_demand,(1-delta)*average_demand-x_demand[centers_depots[i]],0))
            ga3_best = ((1/average_workload)*max(x_workload[centers_depots[i]]-(1+delta)*average_workload,(1-delta)*average_workload-x_workload[centers_depots[i]],0))

            weight_district_best_g = weight_district_best_g + (ga1_best+ga2_best+ga3_best)



        weight_district_best = llambda*weight_district_best_f + (1-llambda)*weight_district_best_g

    #Return True if the first district allocation is better

        if(weight_district_temp<weight_district_best):

            return True
        else:

            return False

    
    def merit_function(x):

        x_customers = {}
        x_demand = {}
        x_workload = {}

        for k in centers_depots:
            x_customers[k] = 0
            x_demand[k] = 0
            x_workload[k] = 0

    #Calculate the total for each  activity measure for each district allocation
        for k in centers_depots:
            for w in x[k]:
                x_customers[k] = x_customers[k] + graph_input.nodes[w]['n_customers']
                x_workload[k] = x_workload[k] + graph_input.nodes[w]['workload']
                x_demand[k] = x_demand[k] + graph_input.nodes[w]['demand']

        weight_district_best_f = (max(shortest_paths_dict[a][b] for i in x for a in x[i]+[i] for b in x[i]+[i]))

        weight_district_best_g = 0
        for i in range(len(centers_depots)):

            ga1_best = ((1/average_customers)*max(x_customers[centers_depots[i]]-(1+delta)*average_customers,(1-delta)*average_customers-x_customers[centers_depots[i]],0))
            ga2_best = ((1/average_demand)*max(x_demand[centers_depots[i]]-(1+delta)*average_demand,(1-delta)*average_demand-x_demand[centers_depots[i]],0))
            ga3_best = ((1/average_workload)*max(x_workload[centers_depots[i]]-(1+delta)*average_workload,(1-delta)*average_workload-x_workload[centers_depots[i]],0))

            weight_district_best_g = weight_district_best_g + (ga1_best+ga2_best+ga3_best)

        weight_district_best = llambda*weight_district_best_f + (1-llambda)*weight_district_best_g

    #Return value of merit function

        return weight_district_best
        
        
        
        
    def update_merit_function(input_solution,k,l,bu):
        x= cp.deepcopy(input_solution)
        x[l].remove(bu)
        x[k].append(bu)

        x_customers = {}
        x_demand = {}
        x_workload = {}

        for k in centers_depots:
            x_customers[k] = 0
            x_demand[k] = 0
            x_workload[k] = 0

        #Calculate the total for each  activity measure for each district allocation
        for k in centers_depots:
            for w in x[k]:
                x_customers[k] = x_customers[k] + graph_input.nodes[w]['n_customers']
                x_workload[k] = x_workload[k] + graph_input.nodes[w]['workload']
                x_demand[k] = x_demand[k] + graph_input.nodes[w]['demand']

        solution_infeasibility = 0
        for i in range(len(centers_depots)):

            ga1_best = ((1/average_customers)*max(x_customers[centers_depots[i]]-(1+delta)*average_customers,(1-delta)*average_customers-x_customers[centers_depots[i]],0))
            ga2_best = ((1/average_demand)*max(x_demand[centers_depots[i]]-(1+delta)*average_demand,(1-delta)*average_demand-x_demand[centers_depots[i]],0))
            ga3_best = ((1/average_workload)*max(x_workload[centers_depots[i]]-(1+delta)*average_workload,(1-delta)*average_workload-x_workload[centers_depots[i]],0))

            solution_infeasibility = solution_infeasibility + (ga1_best+ga2_best+ga3_best)
        

        solution_objective = (max(shortest_paths_dict[a][b] for i in x for a in x[i]+[i] for b in x[i]+[i]))


        weight_district_best = llambda*solution_objective + (1-llambda)*solution_infeasibility

        return weight_district_best
    
    
    district_trial2 = {}
    best_sol = {}

    
    #Copy the current district allocation
    for i in range(len(centers_depots)):
        district_trial2[centers_depots[i]] = district[centers_depots[i]][:]

    for i in range(len(centers_depots)):
        best_sol[centers_depots[i]] = district[centers_depots[i]][:]
        
    node_district_matching = {}
    for k in district:
        for i in district[k]:
            node_district_matching[i] = k


     
    moves = {}
    for depots in centers_depots:
        moves[depots] = []
        for nodes in node_district_matching:
            if node_district_matching[nodes] != depots:
                moves[depots].append(nodes)
#     print(moves)

    depo_choices = {}
    for k in centers_depots:
        depo_choices[k] = [item for item in combinations
                if item[0] == k or item[1] == k]


    choose = random.choice(range(len(centers_depots)))

    k = centers_depots[choose]
    nmoves = 0
    p = len(centers_depots)
    local_optima = False

    number_of_moves = 0
    move_index = 0
    
            
    current_best_objective = merit_function(district)

    current_best_solution = cp.deepcopy(district)

    while(nmoves<1000 and local_optima==False):
        
#         print("Repeating the for loop again")
#         print(current_best_objective)
        improvement = False
        for k in centers_depots:
#             print("Moving to next center",k)
            improvement = False
            basic_unit = 0
#             print("The basic unit is", moves[k][basic_unit])
            while improvement == False and basic_unit <= len(moves[k])-1:
#                 print(moves[k])
#                 print("The basic unit is", moves[k][basic_unit])
#                 for stuff in current_best_solution[k]+[k]:
#                     if moves[k][basic_unit] in adjacent_nodes[stuff]:
                if nx.has_path(graph_input.subgraph(current_best_solution[k]+[k,moves[k][basic_unit]]),k,moves[k][basic_unit]) == True:

                                          
                    new_objective = update_merit_function(current_best_solution,k,node_district_matching[moves[k][basic_unit]],moves[k][basic_unit])
                    if new_objective < current_best_objective:
    #                     print(k)
#                         print("Better Objective found")
                        best_basic_unit = moves[k][basic_unit]
#                         print(best_basic_unit)
                        current_best_objective = new_objective
                        improvement = True
                            
                basic_unit = basic_unit +1
#                 print("Basic unit number", basic_unit)

                if improvement == True:
                    current_best_solution[k].append(best_basic_unit)
                    current_best_solution[node_district_matching[best_basic_unit]].remove(best_basic_unit)
#                     print("Succeeded in improving", current_best_objective)
#                     print("The best basic unit is", best_basic_unit)
                    node_district_matching[best_basic_unit] = k
                    moves[k].remove(best_basic_unit)
                    moves[node_district_matching[best_basic_unit]].append(best_basic_unit)
                    #Three centers equal distribution


        if improvement == True:    
            nmoves = nmoves+1
            local_optima = False
        else:
            local_optima = True
            print("Local Optimum Reached")
            
            
            
    best_obj = max(shortest_paths_dict[a][b] for i in current_best_solution for a in current_best_solution[i]+[i] for b in current_best_solution[i]+[i])
    
    best_sol_customers = {}
    best_sol_workload = {}
    best_sol_demand = {}
    
    for k in centers_depots:
        best_sol_customers[k]=0
        best_sol_demand[k]=0
        best_sol_workload[k]=0
        
    for k in centers_depots:
        for w in current_best_solution[k]:
            best_sol_customers[k] = best_sol_customers[k] + graph_input.nodes[w]['n_customers']
            best_sol_workload[k] = best_sol_workload[k] + graph_input.nodes[w]['workload']
            best_sol_demand[k] = best_sol_demand[k] + graph_input.nodes[w]['demand']
    
    local_infeasible = 0
    
    for i in range(len(centers_depots)):
        local_infeasible = local_infeasible + ((1/average_customers)*max(best_sol_customers[centers_depots[i]]-(1+delta)*average_customers,(1-delta)*average_customers-best_sol_customers[centers_depots[i]],0))+\
            ((1/average_demand)*max(best_sol_demand[centers_depots[i]]-(1+delta)*average_demand,(1-delta)*average_demand-best_sol_demand[centers_depots[i]],0))+\
                ((1/average_workload)*max(best_sol_workload[centers_depots[i]]-(1+delta)*average_workload,(1-delta)*average_workload-best_sol_workload[centers_depots[i]],0))

    #print(local_infeasible)
    
    return best_obj, local_infeasible, current_best_solution

# %%
#07/02/2022

#Depot best improvement
    
#Create a function that calculates the linear combination of infeasibility and dispersion for two selected districts.
def localsearch_depot_best_improvement(district,centers_depots,combinations,adjacent_nodes,average_customers, average_demand,average_workload,shortest_paths_dict,llambda,delta,graph_input):    
   
    #Save value of best solution for comparisons. Onlly calculate the new one. Update when you find a better solution.
    #Update membership of each district. 
    
    
    def decision(x,y):

        y_customers = {}
        y_demand = {}
        y_workload = {}

        x_customers = {}
        x_demand = {}
        x_workload = {}

        for k in centers_depots:
            y_customers[k] = 0
            y_demand[k] = 0
            y_workload[k] = 0
            x_customers[k] = 0
            x_demand[k] = 0
            x_workload[k] = 0

    #Calculate the total for each  activity measure for each district allocation
        for k in centers_depots:
            for w in y[k]:
                y_customers[k] = y_customers[k] + graph_input.nodes[w]['n_customers']
                y_workload[k] = y_workload[k] + graph_input.nodes[w]['workload']
                y_demand[k] = y_demand[k] + graph_input.nodes[w]['demand']
            for w in x[k]:
                x_customers[k] = x_customers[k] + graph_input.nodes[w]['n_customers']
                x_workload[k] = x_workload[k] + graph_input.nodes[w]['workload']
                x_demand[k] = x_demand[k] + graph_input.nodes[w]['demand']






        weight_district_temp_f = (max(shortest_paths_dict[a][b] for i in y for a in y[i] for b in y[i]))
        #weight_district_temp_f = llambda*(max(get_furthest_nodes(graph_input.subgraph(y[centers_depots[i]]))['diameter'] for i in range(len(centers_depots))))

        weight_district_temp_g = 0
        for i in range(len(centers_depots)):

            ga1_temp = ((1/average_customers)*max(y_customers[centers_depots[i]]-(1+delta)*average_customers,(1-delta)*average_customers-y_customers[centers_depots[i]],0))
            ga2_temp = ((1/average_demand)*max(y_demand[centers_depots[i]]-(1+delta)*average_demand,(1-delta)*average_demand-y_demand[centers_depots[i]],0))
            ga3_temp = ((1/average_workload)*max(y_workload[centers_depots[i]]-(1+delta)*average_workload,(1-delta)*average_workload-y_workload[centers_depots[i]],0))

            weight_district_temp_g = weight_district_temp_g +(ga1_temp+ga2_temp+ga3_temp)

        weight_district_temp = llambda*weight_district_temp_f + (1-llambda)*weight_district_temp_g





        weight_district_best_f = (max(shortest_paths_dict[a][b] for i in x for a in x[i] for b in x[i]))
        weight_district_best_g = 0
        for i in range(len(centers_depots)):
            
            ga1_best = ((1/average_customers)*max(x_customers[centers_depots[i]]-(1+delta)*average_customers,(1-delta)*average_customers-x_customers[centers_depots[i]],0))
            ga2_best = ((1/average_demand)*max(x_demand[centers_depots[i]]-(1+delta)*average_demand,(1-delta)*average_demand-x_demand[centers_depots[i]],0))
            ga3_best = ((1/average_workload)*max(x_workload[centers_depots[i]]-(1+delta)*average_workload,(1-delta)*average_workload-x_workload[centers_depots[i]],0))

            weight_district_best_g = weight_district_best_g + (ga1_best+ga2_best+ga3_best)



        weight_district_best = llambda*weight_district_best_f + (1-llambda)*weight_district_best_g

    #Return True if the first district allocation is better

        if(weight_district_temp<weight_district_best):

            return True
        else:

            return False

    
    def merit_function(x):

        x_customers = {}
        x_demand = {}
        x_workload = {}

        for k in centers_depots:
            x_customers[k] = 0
            x_demand[k] = 0
            x_workload[k] = 0

    #Calculate the total for each  activity measure for each district allocation
        for k in centers_depots:
            for w in x[k]:
                x_customers[k] = x_customers[k] + graph_input.nodes[w]['n_customers']
                x_workload[k] = x_workload[k] + graph_input.nodes[w]['workload']
                x_demand[k] = x_demand[k] + graph_input.nodes[w]['demand']

        weight_district_best_f = (max(shortest_paths_dict[a][b] for i in x for a in x[i]+[i] for b in x[i]+[i]))

        weight_district_best_g = 0
        for i in range(len(centers_depots)):

            ga1_best = ((1/average_customers)*max(x_customers[centers_depots[i]]-(1+delta)*average_customers,(1-delta)*average_customers-x_customers[centers_depots[i]],0))
            ga2_best = ((1/average_demand)*max(x_demand[centers_depots[i]]-(1+delta)*average_demand,(1-delta)*average_demand-x_demand[centers_depots[i]],0))
            ga3_best = ((1/average_workload)*max(x_workload[centers_depots[i]]-(1+delta)*average_workload,(1-delta)*average_workload-x_workload[centers_depots[i]],0))

            weight_district_best_g = weight_district_best_g + (ga1_best+ga2_best+ga3_best)

        weight_district_best = llambda*weight_district_best_f + (1-llambda)*weight_district_best_g

    #Return value of merit function

        return weight_district_best
        
        
        
        
    def update_merit_function(input_solution,k,l,bu):
        x= cp.deepcopy(input_solution)
        x[l].remove(bu)
        x[k].append(bu)

        x_customers = {}
        x_demand = {}
        x_workload = {}

        for k in centers_depots:
            x_customers[k] = 0
            x_demand[k] = 0
            x_workload[k] = 0

        #Calculate the total for each  activity measure for each district allocation
        for k in centers_depots:
            for w in x[k]:
                x_customers[k] = x_customers[k] + graph_input.nodes[w]['n_customers']
                x_workload[k] = x_workload[k] + graph_input.nodes[w]['workload']
                x_demand[k] = x_demand[k] + graph_input.nodes[w]['demand']

        solution_infeasibility = 0
        for i in range(len(centers_depots)):

            ga1_best = ((1/average_customers)*max(x_customers[centers_depots[i]]-(1+delta)*average_customers,(1-delta)*average_customers-x_customers[centers_depots[i]],0))
            ga2_best = ((1/average_demand)*max(x_demand[centers_depots[i]]-(1+delta)*average_demand,(1-delta)*average_demand-x_demand[centers_depots[i]],0))
            ga3_best = ((1/average_workload)*max(x_workload[centers_depots[i]]-(1+delta)*average_workload,(1-delta)*average_workload-x_workload[centers_depots[i]],0))

            solution_infeasibility = solution_infeasibility + (ga1_best+ga2_best+ga3_best)
        

        solution_objective = (max(shortest_paths_dict[a][b] for i in x for a in x[i]+[i] for b in x[i]+[i]))


        weight_district_best = llambda*solution_objective + (1-llambda)*solution_infeasibility

        return weight_district_best
    
    
    district_trial2 = {}
    best_sol = {}

    
    #Copy the current district allocation
    for i in range(len(centers_depots)):
        district_trial2[centers_depots[i]] = district[centers_depots[i]][:]

    for i in range(len(centers_depots)):
        best_sol[centers_depots[i]] = district[centers_depots[i]][:]
        
    node_district_matching = {}
    for k in district:
        for i in district[k]:
            node_district_matching[i] = k
#     print(node_district_matching[444])

     
    moves = {}
    for depots in centers_depots:
        moves[depots] = []
        for nodes in node_district_matching:
            if node_district_matching[nodes] != depots:
                moves[depots].append(nodes)
#     print(moves)

    depo_choices = {}
    for k in centers_depots:
        depo_choices[k] = [item for item in combinations
                if item[0] == k or item[1] == k]


    choose = random.choice(range(len(centers_depots)))

    k = centers_depots[choose]
    nmoves = 0
    p = len(centers_depots)
    local_optima = False

    number_of_moves = 0
    move_index = 0
    
            
    current_best_objective = merit_function(district)

    current_best_solution = cp.deepcopy(district)
    
    
    
    while(nmoves<1000 and local_optima == False):
    
#         print("Repeating for loop again")
#         print("The current best objective is", current_best_objective)
        improvement = False
        for basic_unit in list(set(graph_input.nodes)-set(centers_depots)):
#             improvement = False
            center_removed = node_district_matching[basic_unit]
#             print("Basic unit is", basic_unit)
#             print("back here again")
            center_improvement = False
            for centers_to in centers_depots:
                if center_removed != centers_to: 
                    new_objective  = update_merit_function(current_best_solution,centers_to,center_removed,basic_unit)

                    if new_objective < current_best_objective:
#                         print("Better Objective Found", new_objective)
                        best_center = centers_to
                        current_best_objective = new_objective
                        center_improvement = True
#             print(center_improvement)


            if center_improvement == True:
#                 if nx.has_path(graph_input.subgraph(current_best_solution[best_center]+[best_center,basic_unit]),best_center,basic_unit) == True:
                current_best_solution[best_center].append(basic_unit)
                current_best_solution[center_removed].remove(basic_unit)
#                 print("Succeeded in improving", current_best_objective)
#                 print("The best center is", best_center)
                node_district_matching[basic_unit] = best_center
                improvement = True
        
#         print("We testing stuff here")
#         print("Improvement is", improvement)
        if improvement == True:
            nmoves = nmoves+1
            local_optima = False
        else:
            local_optima = True
            print("Local Optimum Reached")
            
            
            
    best_obj = max(shortest_paths_dict[a][b] for i in current_best_solution for a in current_best_solution[i]+[i] for b in current_best_solution[i]+[i])
    
    best_sol_customers = {}
    best_sol_workload = {}
    best_sol_demand = {}
    
    for k in centers_depots:
        best_sol_customers[k]=0
        best_sol_demand[k]=0
        best_sol_workload[k]=0
        
    for k in centers_depots:
        for w in current_best_solution[k]:
            best_sol_customers[k] = best_sol_customers[k] + graph_input.nodes[w]['n_customers']
            best_sol_workload[k] = best_sol_workload[k] + graph_input.nodes[w]['workload']
            best_sol_demand[k] = best_sol_demand[k] + graph_input.nodes[w]['demand']
    
    local_infeasible = 0
    
    for i in range(len(centers_depots)):
        local_infeasible = local_infeasible + ((1/average_customers)*max(best_sol_customers[centers_depots[i]]-(1+delta)*average_customers,(1-delta)*average_customers-best_sol_customers[centers_depots[i]],0))+\
            ((1/average_demand)*max(best_sol_demand[centers_depots[i]]-(1+delta)*average_demand,(1-delta)*average_demand-best_sol_demand[centers_depots[i]],0))+\
                ((1/average_workload)*max(best_sol_workload[centers_depots[i]]-(1+delta)*average_workload,(1-delta)*average_workload-best_sol_workload[centers_depots[i]],0))

    #print(local_infeasible)
    
    return best_obj, local_infeasible, current_best_solution

# %%
#08/02/2022

#Depot First improvement
    
#Create a function that calculates the linear combination of infeasibility and dispersion for two selected districts.
def localsearch_depot_first_improvement(district,centers_depots,combinations,adjacent_nodes,average_customers, average_demand,average_workload,shortest_paths_dict,llambda,delta,graph_input):    
   
    #Save value of best solution for comparisons. Onlly calculate the new one. Update when you find a better solution.
    #Update membership of each district. 
    
    
    def decision(x,y):

        y_customers = {}
        y_demand = {}
        y_workload = {}

        x_customers = {}
        x_demand = {}
        x_workload = {}

        for k in centers_depots:
            y_customers[k] = 0
            y_demand[k] = 0
            y_workload[k] = 0
            x_customers[k] = 0
            x_demand[k] = 0
            x_workload[k] = 0

    #Calculate the total for each  activity measure for each district allocation
        for k in centers_depots:
            for w in y[k]:
                y_customers[k] = y_customers[k] + graph_input.nodes[w]['n_customers']
                y_workload[k] = y_workload[k] + graph_input.nodes[w]['workload']
                y_demand[k] = y_demand[k] + graph_input.nodes[w]['demand']
            for w in x[k]:
                x_customers[k] = x_customers[k] + graph_input.nodes[w]['n_customers']
                x_workload[k] = x_workload[k] + graph_input.nodes[w]['workload']
                x_demand[k] = x_demand[k] + graph_input.nodes[w]['demand']






        weight_district_temp_f = (max(shortest_paths_dict[a][b] for i in y for a in y[i] for b in y[i]))
        #weight_district_temp_f = llambda*(max(get_furthest_nodes(graph_input.subgraph(y[centers_depots[i]]))['diameter'] for i in range(len(centers_depots))))

        weight_district_temp_g = 0
        for i in range(len(centers_depots)):

            ga1_temp = ((1/average_customers)*max(y_customers[centers_depots[i]]-(1+delta)*average_customers,(1-delta)*average_customers-y_customers[centers_depots[i]],0))
            ga2_temp = ((1/average_demand)*max(y_demand[centers_depots[i]]-(1+delta)*average_demand,(1-delta)*average_demand-y_demand[centers_depots[i]],0))
            ga3_temp = ((1/average_workload)*max(y_workload[centers_depots[i]]-(1+delta)*average_workload,(1-delta)*average_workload-y_workload[centers_depots[i]],0))

            weight_district_temp_g = weight_district_temp_g +(ga1_temp+ga2_temp+ga3_temp)

        weight_district_temp = llambda*weight_district_temp_f + (1-llambda)*weight_district_temp_g





        weight_district_best_f = (max(shortest_paths_dict[a][b] for i in x for a in x[i] for b in x[i]))
        weight_district_best_g = 0
        for i in range(len(centers_depots)):
            
            ga1_best = ((1/average_customers)*max(x_customers[centers_depots[i]]-(1+delta)*average_customers,(1-delta)*average_customers-x_customers[centers_depots[i]],0))
            ga2_best = ((1/average_demand)*max(x_demand[centers_depots[i]]-(1+delta)*average_demand,(1-delta)*average_demand-x_demand[centers_depots[i]],0))
            ga3_best = ((1/average_workload)*max(x_workload[centers_depots[i]]-(1+delta)*average_workload,(1-delta)*average_workload-x_workload[centers_depots[i]],0))

            weight_district_best_g = weight_district_best_g + (ga1_best+ga2_best+ga3_best)



        weight_district_best = llambda*weight_district_best_f + (1-llambda)*weight_district_best_g

    #Return True if the first district allocation is better

        if(weight_district_temp<weight_district_best):

            return True
        else:

            return False

    
    def merit_function(x):

        x_customers = {}
        x_demand = {}
        x_workload = {}

        for k in centers_depots:
            x_customers[k] = 0
            x_demand[k] = 0
            x_workload[k] = 0

    #Calculate the total for each  activity measure for each district allocation
        for k in centers_depots:
            for w in x[k]:
                x_customers[k] = x_customers[k] + graph_input.nodes[w]['n_customers']
                x_workload[k] = x_workload[k] + graph_input.nodes[w]['workload']
                x_demand[k] = x_demand[k] + graph_input.nodes[w]['demand']

        weight_district_best_f = (max(shortest_paths_dict[a][b] for i in x for a in x[i]+[i] for b in x[i]+[i]))

        weight_district_best_g = 0
        for i in range(len(centers_depots)):

            ga1_best = ((1/average_customers)*max(x_customers[centers_depots[i]]-(1+delta)*average_customers,(1-delta)*average_customers-x_customers[centers_depots[i]],0))
            ga2_best = ((1/average_demand)*max(x_demand[centers_depots[i]]-(1+delta)*average_demand,(1-delta)*average_demand-x_demand[centers_depots[i]],0))
            ga3_best = ((1/average_workload)*max(x_workload[centers_depots[i]]-(1+delta)*average_workload,(1-delta)*average_workload-x_workload[centers_depots[i]],0))

            weight_district_best_g = weight_district_best_g + (ga1_best+ga2_best+ga3_best)

        weight_district_best = llambda*weight_district_best_f + (1-llambda)*weight_district_best_g

    #Return value of merit function

        return weight_district_best
        
        
        
        
    def update_merit_function(input_solution,k,l,bu):
        x= cp.deepcopy(input_solution)
        x[l].remove(bu)
        x[k].append(bu)

        x_customers = {}
        x_demand = {}
        x_workload = {}

        for k in centers_depots:
            x_customers[k] = 0
            x_demand[k] = 0
            x_workload[k] = 0

        #Calculate the total for each  activity measure for each district allocation
        for k in centers_depots:
            for w in x[k]:
                x_customers[k] = x_customers[k] + graph_input.nodes[w]['n_customers']
                x_workload[k] = x_workload[k] + graph_input.nodes[w]['workload']
                x_demand[k] = x_demand[k] + graph_input.nodes[w]['demand']

        solution_infeasibility = 0
        for i in range(len(centers_depots)):

            ga1_best = ((1/average_customers)*max(x_customers[centers_depots[i]]-(1+delta)*average_customers,(1-delta)*average_customers-x_customers[centers_depots[i]],0))
            ga2_best = ((1/average_demand)*max(x_demand[centers_depots[i]]-(1+delta)*average_demand,(1-delta)*average_demand-x_demand[centers_depots[i]],0))
            ga3_best = ((1/average_workload)*max(x_workload[centers_depots[i]]-(1+delta)*average_workload,(1-delta)*average_workload-x_workload[centers_depots[i]],0))

            solution_infeasibility = solution_infeasibility + (ga1_best+ga2_best+ga3_best)
        

        solution_objective = (max(shortest_paths_dict[a][b] for i in x for a in x[i]+[i] for b in x[i]+[i]))


        weight_district_best = llambda*solution_objective + (1-llambda)*solution_infeasibility

        return weight_district_best
    
    
    district_trial2 = {}
    best_sol = {}

    
    #Copy the current district allocation
    for i in range(len(centers_depots)):
        district_trial2[centers_depots[i]] = district[centers_depots[i]][:]

    for i in range(len(centers_depots)):
        best_sol[centers_depots[i]] = district[centers_depots[i]][:]
        
    node_district_matching = {}
    for k in district:
        for i in district[k]:
            node_district_matching[i] = k


     
    moves = {}
    for depots in centers_depots:
        moves[depots] = []
        for nodes in node_district_matching:
            if node_district_matching[nodes] != depots:
                moves[depots].append(nodes)
#     print(moves)

    depo_choices = {}
    for k in centers_depots:
        depo_choices[k] = [item for item in combinations
                if item[0] == k or item[1] == k]


    choose = random.choice(range(len(centers_depots)))

    k = centers_depots[choose]
    nmoves = 0
    p = len(centers_depots)
    local_optima = False

    number_of_moves = 0
    move_index = 0
    
            
    current_best_objective = merit_function(district)

    current_best_solution = cp.deepcopy(district)
    
    
    
    while(nmoves<1000 and local_optima == False):
    
#         print("Repeating for loop again")
#         print("The current best objective is", current_best_objective)
        improvement = False
        for basic_unit in list(set(graph_input.nodes)-set(centers_depots)):
            improvement = False
            center_removed = node_district_matching[basic_unit]
            center_visited = 0
            while improvement == False and center_visited <= len(centers_depots)-2:
                centers_to = centers_depots[center_visited]
                new_objective  = update_merit_function(current_best_solution,centers_to,center_removed,basic_unit)

                if new_objective < current_best_objective:
#                     print("Better Objective Found")
                    best_center = centers_to
                    current_best_objective = new_objective
                    improvement = True

                
                if improvement == True:
                    current_best_solution[best_center].append(basic_unit)
                    current_best_solution[center_removed].remove(basic_unit)
#                     print("Succeeded in improving", current_best_objective)
#                     print("The best center is", best_center)
                    node_district_matching[basic_unit] = best_center
  
                
                center_visited = center_visited +  1
#                 print(center_visited)
                centers_to = centers_depots[center_visited]

                
        if improvement == True:
            nmoves = nmoves+1
            local_optima = False
        else:
            local_optima = True
            print("Local Optimum Reached")
            
            
            
    best_obj = max(shortest_paths_dict[a][b] for i in current_best_solution for a in current_best_solution[i]+[i] for b in current_best_solution[i]+[i])
    
    best_sol_customers = {}
    best_sol_workload = {}
    best_sol_demand = {}
    
    for k in centers_depots:
        best_sol_customers[k]=0
        best_sol_demand[k]=0
        best_sol_workload[k]=0
        
    for k in centers_depots:
        for w in current_best_solution[k]:
            best_sol_customers[k] = best_sol_customers[k] + graph_input.nodes[w]['n_customers']
            best_sol_workload[k] = best_sol_workload[k] + graph_input.nodes[w]['workload']
            best_sol_demand[k] = best_sol_demand[k] + graph_input.nodes[w]['demand']
    
    local_infeasible = 0
    
    for i in range(len(centers_depots)):
        local_infeasible = local_infeasible + ((1/average_customers)*max(best_sol_customers[centers_depots[i]]-(1+delta)*average_customers,(1-delta)*average_customers-best_sol_customers[centers_depots[i]],0))+\
            ((1/average_demand)*max(best_sol_demand[centers_depots[i]]-(1+delta)*average_demand,(1-delta)*average_demand-best_sol_demand[centers_depots[i]],0))+\
                ((1/average_workload)*max(best_sol_workload[centers_depots[i]]-(1+delta)*average_workload,(1-delta)*average_workload-best_sol_workload[centers_depots[i]],0))

    #print(local_infeasible)
    
    return best_obj, local_infeasible, current_best_solution

# %%
#Depot First Improvement
local_obj, local_infeasible, local_sol = localsearch_grasp(district,centers_depots,combinations,adjacent_nodes,average_customers, average_demand,average_workload,shortest_paths_dict,0.3,0.05,G1)
# Out:
# Repeating for loop again
# The current best objective is 140.7459365939455
# Better Objective Found
# Succeeded in improving 140.7381507010778
# The best center is 197
# Better Objective Found
# Succeeded in improving 140.71065892006712
# The best center is 197
# Better Objective Found
# Succeeded in improving 140.70494007840324
# The best center is 197
# Better Objective Found
# Succeeded in improving 140.6958057791336
# The best center is 197
# Better Objective Found
# Succeeded in improving 140.65603475364088
# The best center is 28
# Better Objective Found
# Succeeded in improving 140.60007739192966
# The best center is 28
# Better Objective Found
# Succeeded in improving 140.58766968343252
# The best center is 28
# Better Objective Found
# Succeeded in improving 140.56777605859128
# The best center is 28
# Better Objective Found
# Succeeded in improving 140.5464615226628
# The best center is 28
# Better Objective Found
# Succeeded in improving 140.51958985701324
# The best center is 197
# Better Objective Found
# Succeeded in improving 140.5095598355553
# The best center is 197
# Better Objective Found
# Succeeded in improving 140.48814320742906
# The best center is 28
# Better Objective Found
# Succeeded in improving 140.48366065735615
# The best center is 197
# Better Objective Found
# Succeeded in improving 140.4770252380954
# The best center is 197
# Better Objective Found
# Succeeded in improving 140.4403589833524
# The best center is 143
# Better Objective Found
# Succeeded in improving 140.4224499695881
# The best center is 143
# Better Objective Found
# Succeeded in improving 140.42241836861166
# The best center is 28
# Better Objective Found
# Succeeded in improving 140.42126162166227
# The best center is 197
# Better Objective Found
# Succeeded in improving 140.40251751473707
# The best center is 143
# Better Objective Found
# Succeeded in improving 140.35827413174542
# The best center is 143
# Better Objective Found
# Succeeded in improving 140.3527033739948
# The best center is 143
# Better Objective Found
# Succeeded in improving 140.3286270505899
# The best center is 694
# Better Objective Found
# Succeeded in improving 140.31174613242544
# The best center is 694
# Better Objective Found
# Succeeded in improving 140.2877683384612
# The best center is 694
# Better Objective Found
# Succeeded in improving 140.27684259481495
# The best center is 197
# Better Objective Found
# Succeeded in improving 140.27637249068874
# The best center is 28
# Better Objective Found
# Succeeded in improving 139.10309346466056
# The best center is 143
# Better Objective Found
# Succeeded in improving 139.09041555061052
# The best center is 694
# Better Objective Found
# Succeeded in improving 139.08790959553443
# The best center is 694
# Better Objective Found
# Succeeded in improving 139.0843358474288
# The best center is 258
# Better Objective Found
# Succeeded in improving 139.08118685600257
# The best center is 28
# Better Objective Found
# Succeeded in improving 139.02677581348573
# The best center is 143
# Better Objective Found
# Succeeded in improving 139.00504482494648
# The best center is 143
# Better Objective Found
# Succeeded in improving 138.9759048329748
# The best center is 143
# Better Objective Found
# Succeeded in improving 138.929825881136
# The best center is 143
# Better Objective Found
# Succeeded in improving 138.91443377827545
# The best center is 143
# Better Objective Found
# Succeeded in improving 138.90261258622246
# The best center is 143
# Better Objective Found
# Succeeded in improving 138.84105240714308
# The best center is 258
# Better Objective Found
# Succeeded in improving 138.83989566019372
# The best center is 197
# Better Objective Found
# Succeeded in improving 138.7712058372326
# The best center is 28
# Better Objective Found
# Succeeded in improving 138.69667148898688
# The best center is 28
# Better Objective Found
# Succeeded in improving 138.6533241618986
# The best center is 28
# Better Objective Found
# Succeeded in improving 138.5641787053276
# The best center is 28
# Better Objective Found
# Succeeded in improving 138.52415576865582
# The best center is 28
# Better Objective Found
# Succeeded in improving 138.45026020086794
# The best center is 258
# Better Objective Found
# Succeeded in improving 138.4090119082948
# The best center is 258
# Better Objective Found
# Succeeded in improving 138.3899249610537
# The best center is 197
# Better Objective Found
# Succeeded in improving 138.34514407576714
# The best center is 28
# Better Objective Found
# Succeeded in improving 138.31248289327013
# The best center is 28
# Better Objective Found
# Succeeded in improving 138.28322192620695
# The best center is 28
# Better Objective Found
# Succeeded in improving 138.25253377490193
# The best center is 28
# Better Objective Found
# Succeeded in improving 138.23551769817695
# The best center is 28
# Better Objective Found
# Succeeded in improving 138.23412696970013
# The best center is 28
# Better Objective Found
# Succeeded in improving 138.18260859080283
# The best center is 258
# Better Objective Found
# Succeeded in improving 138.13985575040655
# The best center is 258
# Better Objective Found
# Succeeded in improving 138.06019844429147
# The best center is 258
# Better Objective Found
# Succeeded in improving 138.03126179781324
# The best center is 258
# Better Objective Found
# Succeeded in improving 137.972675209272
# The best center is 258
# Better Objective Found
# Succeeded in improving 137.92929831682102
# The best center is 352
# Better Objective Found
# Succeeded in improving 137.90371137206097
# The best center is 352
# Better Objective Found
# Succeeded in improving 137.87536992147798
# The best center is 352
# Better Objective Found
# Succeeded in improving 137.8535606579181
# The best center is 352
# Better Objective Found
# Succeeded in improving 137.83979697802394
# The best center is 352
# Better Objective Found
# Succeeded in improving 137.74070307385256
# The best center is 258
# Better Objective Found
# Succeeded in improving 137.6624898189713
# The best center is 258
# Better Objective Found
# Succeeded in improving 137.62350271656123
# The best center is 258
# Better Objective Found
# Succeeded in improving 137.51950195819683
# The best center is 352
# Better Objective Found
# Succeeded in improving 137.45255480255676
# The best center is 352
# Better Objective Found
# Succeeded in improving 137.44364098874885
# The best center is 694
# Better Objective Found
# Succeeded in improving 137.42696677570476
# The best center is 258
# Better Objective Found
# Succeeded in improving 137.4178028487012
# The best center is 258
# Better Objective Found
# Succeeded in improving 137.41074938097674
# The best center is 258
# Better Objective Found
# Succeeded in improving 137.30691859915308
# The best center is 352
# Better Objective Found
# Succeeded in improving 137.2319145912962
# The best center is 352
# Better Objective Found
# Succeeded in improving 137.22925440954583
# The best center is 258
# Better Objective Found
# Succeeded in improving 137.20555222240878
# The best center is 258
# Better Objective Found
# Succeeded in improving 137.1922541929976
# The best center is 258
# Better Objective Found
# Succeeded in improving 137.19085066523022
# The best center is 258
# Better Objective Found
# Succeeded in improving 137.10621790750776
# The best center is 352
# Better Objective Found
# Succeeded in improving 137.02464030366184
# The best center is 352
# Better Objective Found
# Succeeded in improving 136.97368707995884
# The best center is 352
# Better Objective Found
# Succeeded in improving 136.89113290822817
# The best center is 352
# Better Objective Found
# Succeeded in improving 136.8456871655421
# The best center is 352
# Better Objective Found
# Succeeded in improving 136.749460582343
# The best center is 352
# Better Objective Found
# Succeeded in improving 136.7462911038305
# The best center is 694
# Better Objective Found
# Succeeded in improving 136.69655214220018
# The best center is 352
# Better Objective Found
# Succeeded in improving 136.61885340437524
# The best center is 352
# Better Objective Found
# Succeeded in improving 136.5282555819595
# The best center is 352
# Better Objective Found
# Succeeded in improving 136.4605351067955
# The best center is 352
# Better Objective Found
# Succeeded in improving 136.38497813456343
# The best center is 352
# Better Objective Found
# Succeeded in improving 136.37925929289955
# The best center is 258
# Better Objective Found
# Succeeded in improving 136.3687862334669
# The best center is 694
# Better Objective Found
# Succeeded in improving 136.3521809221296
# The best center is 694
# Better Objective Found
# Succeeded in improving 136.33089029473035
# The best center is 694
# Better Objective Found
# Succeeded in improving 136.3251025513597
# The best center is 694
# Better Objective Found
# Succeeded in improving 136.313777177814
# The best center is 694
# Better Objective Found
# Succeeded in improving 136.31081440442188
# The best center is 258
# Better Objective Found
# Succeeded in improving 136.24636170062865
# The best center is 352
# Better Objective Found
# Succeeded in improving 136.1636429750056
# The best center is 352
# Better Objective Found
# Succeeded in improving 136.10274281877795
# The best center is 352
# Better Objective Found
# Succeeded in improving 136.102513952275
# The best center is 694
# Better Objective Found
# Succeeded in improving 135.99619886956705
# The best center is 352
# Better Objective Found
# Succeeded in improving 135.9411539941418
# The best center is 352
# Better Objective Found
# Succeeded in improving 135.86828733068694
# The best center is 352
# Better Objective Found
# Succeeded in improving 135.78935243522042
# The best center is 352
# Better Objective Found
# Succeeded in improving 135.75989270459735
# The best center is 352
# Better Objective Found
# Succeeded in improving 135.73117270267045
# The best center is 352
# Better Objective Found
# Succeeded in improving 135.66884679042855
# The best center is 352
# Better Objective Found
# Succeeded in improving 135.6227096226758
# The best center is 352
# Better Objective Found
# Succeeded in improving 135.55610189399013
# The best center is 352
# Better Objective Found
# Succeeded in improving 135.4986207232022
# The best center is 352
# Better Objective Found
# Succeeded in improving 135.45189456445468
# The best center is 352
# Better Objective Found
# Succeeded in improving 135.40454999669404
# The best center is 352
# Better Objective Found
# Succeeded in improving 135.37196541995527
# The best center is 352
# Better Objective Found
# Succeeded in improving 135.3338183993338
# The best center is 352
# Better Objective Found
# Succeeded in improving 135.30544837620482
# The best center is 352
# Better Objective Found
# Succeeded in improving 135.3031366799439
# The best center is 352
# Better Objective Found
# Succeeded in improving 135.29852973828184
# The best center is 352
# Better Objective Found
# Succeeded in improving 135.29441260709135
# The best center is 352
# Better Objective Found
# Succeeded in improving 135.29149256350502
# The best center is 565
# Better Objective Found
# Succeeded in improving 135.29096969475992
# The best center is 352
# Better Objective Found
# Succeeded in improving 135.00828656409533
# The best center is 565
# Repeating for loop again
# The current best objective is 135.00828656409533
# Better Objective Found
# Succeeded in improving 134.96464750459347
# The best center is 197
# Better Objective Found
# Succeeded in improving 134.91943324426407
# The best center is 197
# Better Objective Found
# Succeeded in improving 134.85314425975125
# The best center is 197
# Better Objective Found
# Succeeded in improving 134.82252033294
# The best center is 197
# Better Objective Found
# Succeeded in improving 134.7934882747267
# The best center is 197
# Better Objective Found
# Succeeded in improving 134.74227128327698
# The best center is 197
# Better Objective Found
# Succeeded in improving 134.71043953881744
# The best center is 197
# Better Objective Found
# Succeeded in improving 134.6905543206049
# The best center is 197
# Better Objective Found
# Succeeded in improving 134.64217730287
# The best center is 28
# Better Objective Found
# Succeeded in improving 134.5832238528534
# The best center is 28
# Better Objective Found
# Succeeded in improving 134.5416049363665
# The best center is 197
# Better Objective Found
# Succeeded in improving 134.49164021567628
# The best center is 197
# Better Objective Found
# Succeeded in improving 134.46876484902077
# The best center is 197
# Better Objective Found
# Succeeded in improving 134.45367537523296
# The best center is 197
# Better Objective Found
# Succeeded in improving 134.4409078175772
# The best center is 28
# Better Objective Found
# Succeeded in improving 134.42083216129214
# The best center is 28
# Better Objective Found
# Succeeded in improving 134.4042599526785
# The best center is 28
# Better Objective Found
# Succeeded in improving 134.3940612771818
# The best center is 28
# Better Objective Found
# Succeeded in improving 134.3677559422447
# The best center is 197
# Better Objective Found
# Succeeded in improving 134.33601377073936
# The best center is 197
# Better Objective Found
# Succeeded in improving 134.32006794401553
# The best center is 197
# Better Objective Found
# Succeeded in improving 134.29082597224132
# The best center is 197
# Better Objective Found
# Succeeded in improving 134.23853216646654
# The best center is 143
# Better Objective Found
# Succeeded in improving 134.2085145010821
# The best center is 143
# Better Objective Found
# Succeeded in improving 134.17319058818768
# The best center is 143
# Better Objective Found
# Succeeded in improving 134.15238705350868
# The best center is 143
# Better Objective Found
# Succeeded in improving 134.14391108034738
# The best center is 143
# Better Objective Found
# Succeeded in improving 134.1101736448804
# The best center is 694
# Better Objective Found
# Succeeded in improving 134.10771178910278
# The best center is 694
# Better Objective Found
# Succeeded in improving 134.09316355930721
# The best center is 28
# Better Objective Found
# Succeeded in improving 134.07131383999092
# The best center is 197
# Better Objective Found
# Succeeded in improving 134.04355666292784
# The best center is 28
# Better Objective Found
# Succeeded in improving 134.03090710687306
# The best center is 197
# Better Objective Found
# Succeeded in improving 134.01694968812785
# The best center is 197
# Better Objective Found
# Succeeded in improving 134.00476797639072
# The best center is 28
# Better Objective Found
# Succeeded in improving 133.98156034851638
# The best center is 197
# Better Objective Found
# Succeeded in improving 133.9491599966694
# The best center is 197
# Better Objective Found
# Succeeded in improving 133.93409377150385
# The best center is 197
# Better Objective Found
# Succeeded in improving 133.93349100218256
# The best center is 28
# Better Objective Found
# Succeeded in improving 133.9154387550026
# The best center is 694
# Better Objective Found
# Succeeded in improving 133.8960525808537
# The best center is 197
# Better Objective Found
# Succeeded in improving 133.88499429627294
# The best center is 467
# Better Objective Found
# Succeeded in improving 133.8818292910273
# The best center is 467
# Better Objective Found
# Succeeded in improving 133.8792603068601
# The best center is 258
# Better Objective Found
# Succeeded in improving 133.8720748763965
# The best center is 28
# Better Objective Found
# Succeeded in improving 133.85745847201846
# The best center is 467
# Better Objective Found
# Succeeded in improving 133.8266294444672
# The best center is 28
# Better Objective Found
# Succeeded in improving 133.8035536213764
# The best center is 258
# Better Objective Found
# Succeeded in improving 133.79959817499326
# The best center is 197
# Better Objective Found
# Succeeded in improving 133.78560949707594
# The best center is 28
# Better Objective Found
# Succeeded in improving 133.78512756045484
# The best center is 467
# Better Objective Found
# Succeeded in improving 133.78139210206072
# The best center is 258
# Better Objective Found
# Succeeded in improving 133.74496006635422
# The best center is 258
# Better Objective Found
# Succeeded in improving 133.73861029462094
# The best center is 258
# Better Objective Found
# Succeeded in improving 133.73248319893673
# The best center is 352
# Better Objective Found
# Succeeded in improving 133.72554135664305
# The best center is 143
# Better Objective Found
# Succeeded in improving 133.72514080101524
# The best center is 143
# Better Objective Found
# Succeeded in improving 133.72447171068595
# The best center is 197
# Better Objective Found
# Succeeded in improving 133.7160400204805
# The best center is 197
# Better Objective Found
# Succeeded in improving 133.6842538560162
# The best center is 258
# Better Objective Found
# Succeeded in improving 133.64803545869052
# The best center is 258
# Better Objective Found
# Succeeded in improving 133.62051977816643
# The best center is 258
# Better Objective Found
# Succeeded in improving 133.61580815625413
# The best center is 143
# Better Objective Found
# Succeeded in improving 133.02595094005767
# The best center is 467
# Better Objective Found
# Succeeded in improving 133.00934562872038
# The best center is 258
# Better Objective Found
# Succeeded in improving 133.00307557340216
# The best center is 258
# Better Objective Found
# Succeeded in improving 132.98915077573656
# The best center is 694
# Better Objective Found
# Succeeded in improving 132.98884554117546
# The best center is 694
# Better Objective Found
# Succeeded in improving 132.97733498588443
# The best center is 258
# Better Objective Found
# Succeeded in improving 132.97050300165597
# The best center is 352
# Better Objective Found
# Succeeded in improving 132.9682809399044
# The best center is 352
# Better Objective Found
# Succeeded in improving 132.9658386675206
# The best center is 694
# Better Objective Found
# Succeeded in improving 132.95120350435843
# The best center is 352
# Better Objective Found
# Succeeded in improving 132.93831155511356
# The best center is 352
# Local Optimum Reached

# %%
#Depot best Improvement
local_obj, local_infeasible, local_sol = localsearch_depot_best_improvement(district,centers_depots,combinations,adjacent_nodes,average_customers, average_demand,average_workload,shortest_paths_dict,0.3,0.05,G1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_54319/1909136706.py in <module>
#       1 #Depot best Improvement
# ----> 2 local_obj, local_infeasible, local_sol = localsearch_depot_best_improvement(district,centers_depots,combinations,adjacent_nodes,average_customers, average_demand,average_workload,shortest_paths_dict,0.3,0.05,G1)
#
# /tmp/ipykernel_54319/4209115668.py in localsearch_depot_best_improvement(district, centers_depots, combinations, adjacent_nodes, average_customers, average_demand, average_workload, shortest_paths_dict, llambda, delta, graph_input)
#     178         for i in district[k]:
#     179             node_district_matching[i] = k
# --> 180     print(node_district_matching[444])
#     181
#     182
#
# KeyError: 444

# %%
#First Improvement
local_obj, local_infeasible, local_sol = localsearch_grasp(district,centers_depots,combinations,adjacent_nodes,average_customers, average_demand,average_workload,shortest_paths_dict,0.3,0.05,G1)
# Out:
# Repeating the for loop again
# 227.01446500673808
# Moving to next center 462
# Moving to next center 404
# Better Objective found
# 186
# Succeeded in improving 226.99588298024065
# The best basic unit is 186
# Moving to next center 128
# Better Objective found
# 265
# Succeeded in improving 226.9854879178551
# The best basic unit is 265
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Better Objective found
# 283
# Succeeded in improving 226.90939639060983
# The best basic unit is 283
# Moving to next center 357
# Better Objective found
# 409
# Succeeded in improving 226.8794268765831
# The best basic unit is 409
# Moving to next center 702
# Better Objective found
# 594
# Succeeded in improving 226.8731524511412
# The best basic unit is 594
# Moving to next center 470
# Better Objective found
# 466
# Succeeded in improving 226.85132336828894
# The best basic unit is 466
# Moving to next center 481
# Better Objective found
# 457
# Succeeded in improving 226.83042745707377
# The best basic unit is 457
# Repeating the for loop again
# 226.83042745707377
# Moving to next center 462
# Better Objective found
# 411
# Succeeded in improving 226.82275790053635
# The best basic unit is 411
# Moving to next center 404
# Better Objective found
# 185
# Succeeded in improving 226.8144564624594
# The best basic unit is 185
# Moving to next center 128
# Better Objective found
# 263
# Succeeded in improving 226.79011750464662
# The best basic unit is 263
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Better Objective found
# 256
# Succeeded in improving 226.75233794434257
# The best basic unit is 256
# Moving to next center 357
# Better Objective found
# 436
# Succeeded in improving 226.73552642928198
# The best basic unit is 436
# Moving to next center 702
# Better Objective found
# 567
# Succeeded in improving 226.73203562855497
# The best basic unit is 567
# Moving to next center 470
# Better Objective found
# 465
# Succeeded in improving 226.71815152117998
# The best basic unit is 465
# Moving to next center 481
# Better Objective found
# 430
# Succeeded in improving 226.69606485700882
# The best basic unit is 430
# Repeating the for loop again
# 226.69606485700882
# Moving to next center 462
# Better Objective found
# 412
# Succeeded in improving 226.6951119593714
# The best basic unit is 412
# Moving to next center 404
# Better Objective found
# 158
# Succeeded in improving 226.67955138427547
# The best basic unit is 158
# Moving to next center 128
# Better Objective found
# 262
# Succeeded in improving 226.66110591705956
# The best basic unit is 262
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Better Objective found
# 258
# Succeeded in improving 226.6229374983843
# The best basic unit is 258
# Moving to next center 357
# Better Objective found
# 463
# Succeeded in improving 226.58646659678925
# The best basic unit is 463
# Moving to next center 702
# Moving to next center 470
# Better Objective found
# 464
# Succeeded in improving 226.58424251652167
# The best basic unit is 464
# Moving to next center 481
# Better Objective found
# 403
# Succeeded in improving 226.5388016702297
# The best basic unit is 403
# Repeating the for loop again
# 226.5388016702297
# Moving to next center 462
# Better Objective found
# 621
# Succeeded in improving 226.51527324213606
# The best basic unit is 621
# Moving to next center 404
# Better Objective found
# 157
# Succeeded in improving 226.4691007228229
# The best basic unit is 157
# Moving to next center 128
# Better Objective found
# 289
# Succeeded in improving 226.4572599843188
# The best basic unit is 289
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Better Objective found
# 231
# Succeeded in improving 226.4323434844954
# The best basic unit is 231
# Moving to next center 357
# Better Objective found
# 437
# Succeeded in improving 226.42075485573284
# The best basic unit is 437
# Moving to next center 702
# Moving to next center 470
# Better Objective found
# 389
# Succeeded in improving 226.3616393611349
# The best basic unit is 389
# Moving to next center 481
# Better Objective found
# 376
# Succeeded in improving 226.32753735656183
# The best basic unit is 376
# Repeating the for loop again
# 226.32753735656183
# Moving to next center 462
# Better Objective found
# 648
# Succeeded in improving 226.32379153716383
# The best basic unit is 648
# Moving to next center 404
# Better Objective found
# 130
# Succeeded in improving 226.27511963869063
# The best basic unit is 130
# Moving to next center 128
# Better Objective found
# 316
# Succeeded in improving 226.26458452163376
# The best basic unit is 316
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Better Objective found
# 233
# Succeeded in improving 226.2501679618831
# The best basic unit is 233
# Moving to next center 357
# Better Objective found
# 410
# Succeeded in improving 226.232609433455
# The best basic unit is 410
# Moving to next center 702
# Moving to next center 470
# Better Objective found
# 491
# Succeeded in improving 226.23038535318744
# The best basic unit is 491
# Moving to next center 481
# Better Objective found
# 377
# Succeeded in improving 226.18177946071557
# The best basic unit is 377
# Repeating the for loop again
# 226.18177946071557
# Moving to next center 462
# Better Objective found
# 675
# Succeeded in improving 226.17815069817377
# The best basic unit is 675
# Moving to next center 404
# Moving to next center 128
# Better Objective found
# 315
# Succeeded in improving 226.15708046406007
# The best basic unit is 315
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Better Objective found
# 234
# Succeeded in improving 226.1312759463494
# The best basic unit is 234
# Moving to next center 357
# Better Objective found
# 438
# Succeeded in improving 226.1219113978544
# The best basic unit is 438
# Moving to next center 702
# Moving to next center 470
# Better Objective found
# 518
# Succeeded in improving 226.11617561190124
# The best basic unit is 518
# Moving to next center 481
# Better Objective found
# 402
# Succeeded in improving 226.09721224734741
# The best basic unit is 402
# Repeating the for loop again
# 226.09721224734741
# Moving to next center 462
# Better Objective found
# 649
# Succeeded in improving 226.08421893631063
# The best basic unit is 649
# Moving to next center 404
# Moving to next center 128
# Better Objective found
# 342
# Succeeded in improving 226.07953666206313
# The best basic unit is 342
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Better Objective found
# 261
# Succeeded in improving 226.06472901802027
# The best basic unit is 261
# Moving to next center 357
# Better Objective found
# 408
# Succeeded in improving 226.05899323206708
# The best basic unit is 408
# Moving to next center 702
# Moving to next center 470
# Better Objective found
# 362
# Succeeded in improving 225.9555086417992
# The best basic unit is 362
# Moving to next center 481
# Better Objective found
# 349
# Succeeded in improving 225.93310868666873
# The best basic unit is 349
# Repeating the for loop again
# 225.93310868666873
# Moving to next center 462
# Better Objective found
# 650
# Succeeded in improving 225.9260852752975
# The best basic unit is 650
# Moving to next center 404
# Moving to next center 128
# Better Objective found
# 343
# Succeeded in improving 225.91906186392626
# The best basic unit is 343
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Better Objective found
# 230
# Succeeded in improving 225.902999334795
# The best basic unit is 230
# Moving to next center 357
# Better Objective found
# 407
# Succeeded in improving 225.8984341174037
# The best basic unit is 407
# Moving to next center 702
# Moving to next center 470
# Better Objective found
# 363
# Succeeded in improving 225.8353874118332
# The best basic unit is 363
# Moving to next center 481
# Better Objective found
# 322
# Succeeded in improving 225.82496935163255
# The best basic unit is 322
# Repeating the for loop again
# 225.82496935163255
# Moving to next center 462
# Moving to next center 404
# Moving to next center 128
# Better Objective found
# 369
# Succeeded in improving 225.8132636660138
# The best basic unit is 369
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Better Objective found
# 203
# Succeeded in improving 225.80860678745083
# The best basic unit is 203
# Moving to next center 357
# Better Objective found
# 332
# Succeeded in improving 225.7543866066265
# The best basic unit is 332
# Moving to next center 702
# Moving to next center 470
# Better Objective found
# 365
# Succeeded in improving 225.69756560946058
# The best basic unit is 365
# Moving to next center 481
# Better Objective found
# 348
# Succeeded in improving 225.69756560946055
# The best basic unit is 348
# Repeating the for loop again
# 225.69756560946055
# Moving to next center 462
# Moving to next center 404
# Moving to next center 128
# Better Objective found
# 370
# Succeeded in improving 225.69300039206925
# The best basic unit is 370
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Better Objective found
# 201
# Succeeded in improving 225.69261012280677
# The best basic unit is 201
# Moving to next center 357
# Better Objective found
# 333
# Succeeded in improving 225.6243077666781
# The best basic unit is 333
# Moving to next center 702
# Moving to next center 470
# Better Objective found
# 366
# Succeeded in improving 225.51850892590076
# The best basic unit is 366
# Moving to next center 481
# Better Objective found
# 479
# Succeeded in improving 225.4427060006786
# The best basic unit is 479
# Repeating the for loop again
# 225.4427060006786
# Moving to next center 462
# Moving to next center 404
# Moving to next center 128
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Moving to next center 357
# Better Objective found
# 334
# Succeeded in improving 225.385215005854
# The best basic unit is 334
# Moving to next center 702
# Moving to next center 470
# Better Objective found
# 339
# Succeeded in improving 225.3175976075321
# The best basic unit is 339
# Moving to next center 481
# Better Objective found
# 452
# Succeeded in improving 225.24554658697443
# The best basic unit is 452
# Repeating the for loop again
# 225.24554658697443
# Moving to next center 462
# Moving to next center 404
# Moving to next center 128
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Better Objective found
# 200
# Succeeded in improving 225.2375153224088
# The best basic unit is 200
# Moving to next center 357
# Better Objective found
# 307
# Succeeded in improving 225.1355345039458
# The best basic unit is 307
# Moving to next center 702
# Moving to next center 470
# Better Objective found
# 312
# Succeeded in improving 225.0386836193052
# The best basic unit is 312
# Moving to next center 481
# Better Objective found
# 451
# Succeeded in improving 224.95377292332586
# The best basic unit is 451
# Repeating the for loop again
# 224.95377292332586
# Moving to next center 462
# Moving to next center 404
# Moving to next center 128
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Better Objective found
# 284
# Succeeded in improving 224.9363162168614
# The best basic unit is 284
# Moving to next center 357
# Better Objective found
# 308
# Succeeded in improving 224.83570993922055
# The best basic unit is 308
# Moving to next center 702
# Moving to next center 470
# Better Objective found
# 313
# Succeeded in improving 224.70026706892068
# The best basic unit is 313
# Moving to next center 481
# Better Objective found
# 424
# Succeeded in improving 224.59173137576195
# The best basic unit is 424
# Repeating the for loop again
# 224.59173137576195
# Moving to next center 462
# Moving to next center 404
# Moving to next center 128
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Better Objective found
# 262
# Succeeded in improving 224.5867098628466
# The best basic unit is 262
# Moving to next center 357
# Better Objective found
# 281
# Succeeded in improving 224.4866275136098
# The best basic unit is 281
# Moving to next center 702
# Moving to next center 470
# Better Objective found
# 286
# Succeeded in improving 224.3823412630699
# The best basic unit is 286
# Moving to next center 481
# Better Objective found
# 397
# Succeeded in improving 224.30202655147576
# The best basic unit is 397
# Repeating the for loop again
# 224.30202655147576
# Moving to next center 462
# Moving to next center 404
# Moving to next center 128
# Better Objective found
# 290
# Succeeded in improving 224.2916084912751
# The best basic unit is 290
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Better Objective found
# 289
# Succeeded in improving 224.27382823448033
# The best basic unit is 289
# Moving to next center 357
# Better Objective found
# 254
# Succeeded in improving 224.21095881836152
# The best basic unit is 254
# Moving to next center 702
# Moving to next center 470
# Better Objective found
# 287
# Succeeded in improving 224.0685758080663
# The best basic unit is 287
# Moving to next center 481
# Better Objective found
# 370
# Succeeded in improving 224.0249425823254
# The best basic unit is 370
# Repeating the for loop again
# 224.0249425823254
# Moving to next center 462
# Moving to next center 404
# Moving to next center 128
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Better Objective found
# 316
# Succeeded in improving 224.01217169676136
# The best basic unit is 316
# Moving to next center 357
# Better Objective found
# 280
# Succeeded in improving 223.94020192385847
# The best basic unit is 280
# Moving to next center 702
# Moving to next center 470
# Better Objective found
# 393
# Succeeded in improving 223.86459479187513
# The best basic unit is 393
# Moving to next center 481
# Better Objective found
# 343
# Succeeded in improving 223.81419644783477
# The best basic unit is 343
# Repeating the for loop again
# 223.81419644783477
# Moving to next center 462
# Moving to next center 404
# Moving to next center 128
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Better Objective found
# 315
# Succeeded in improving 223.78792707873026
# The best basic unit is 315
# Moving to next center 357
# Better Objective found
# 306
# Succeeded in improving 223.7461275878017
# The best basic unit is 306
# Moving to next center 702
# Moving to next center 470
# Better Objective found
# 392
# Succeeded in improving 223.68537585062055
# The best basic unit is 392
# Moving to next center 481
# Better Objective found
# 342
# Succeeded in improving 223.62728758544614
# The best basic unit is 342
# Repeating the for loop again
# 223.62728758544614
# Moving to next center 462
# Moving to next center 404
# Moving to next center 128
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Better Objective found
# 310
# Succeeded in improving 223.59751155455473
# The best basic unit is 310
# Moving to next center 357
# Better Objective found
# 305
# Succeeded in improving 223.54735363124243
# The best basic unit is 305
# Moving to next center 702
# Moving to next center 470
# Better Objective found
# 420
# Succeeded in improving 223.47222384063764
# The best basic unit is 420
# Moving to next center 481
# Better Objective found
# 315
# Succeeded in improving 223.3795781650135
# The best basic unit is 315
# Repeating the for loop again
# 223.3795781650135
# Moving to next center 462
# Moving to next center 404
# Moving to next center 128
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Better Objective found
# 199
# Succeeded in improving 223.35022290708272
# The best basic unit is 199
# Moving to next center 357
# Better Objective found
# 279
# Succeeded in improving 223.3094348688929
# The best basic unit is 279
# Moving to next center 702
# Moving to next center 470
# Better Objective found
# 391
# Succeeded in improving 223.23517793908633
# The best basic unit is 391
# Moving to next center 481
# Better Objective found
# 316
# Succeeded in improving 223.19512358183147
# The best basic unit is 316
# Repeating the for loop again
# 223.19512358183147
# Moving to next center 462
# Moving to next center 404
# Moving to next center 128
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Better Objective found
# 263
# Succeeded in improving 223.19437279470407
# The best basic unit is 263
# Moving to next center 357
# Better Objective found
# 360
# Succeeded in improving 223.15519221270307
# The best basic unit is 360
# Moving to next center 702
# Moving to next center 470
# Better Objective found
# 419
# Succeeded in improving 223.07931995550672
# The best basic unit is 419
# Moving to next center 481
# Better Objective found
# 369
# Succeeded in improving 223.0597303387697
# The best basic unit is 369
# Repeating the for loop again
# 223.0597303387697
# Moving to next center 462
# Moving to next center 404
# Moving to next center 128
# Better Objective found
# 263
# Succeeded in improving 223.05738920164595
# The best basic unit is 263
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Better Objective found
# 172
# Succeeded in improving 223.0152417434983
# The best basic unit is 172
# Moving to next center 357
# Better Objective found
# 278
# Succeeded in improving 222.97438125278498
# The best basic unit is 278
# Moving to next center 702
# Moving to next center 470
# Better Objective found
# 560
# Succeeded in improving 222.9250478885127
# The best basic unit is 560
# Moving to next center 481
# Better Objective found
# 289
# Succeeded in improving 222.91301311887628
# The best basic unit is 289
# Repeating the for loop again
# 222.91301311887628
# Moving to next center 462
# Moving to next center 404
# Moving to next center 128
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Better Objective found
# 198
# Succeeded in improving 222.82688643321143
# The best basic unit is 198
# Moving to next center 357
# Better Objective found
# 304
# Succeeded in improving 222.8218056606986
# The best basic unit is 304
# Moving to next center 702
# Moving to next center 470
# Better Objective found
# 561
# Succeeded in improving 222.79002462141872
# The best basic unit is 561
# Moving to next center 481
# Better Objective found
# 262
# Succeeded in improving 222.78923744497467
# The best basic unit is 262
# Repeating the for loop again
# 222.78923744497467
# Moving to next center 462
# Moving to next center 404
# Moving to next center 128
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Better Objective found
# 226
# Succeeded in improving 222.68657576094296
# The best basic unit is 226
# Moving to next center 357
# Better Objective found
# 464
# Succeeded in improving 222.6736868362002
# The best basic unit is 464
# Moving to next center 702
# Moving to next center 470
# Better Objective found
# 562
# Succeeded in improving 222.66370544948512
# The best basic unit is 562
# Moving to next center 481
# Better Objective found
# 290
# Succeeded in improving 222.6349368553739
# The best basic unit is 290
# Repeating the for loop again
# 222.6349368553739
# Moving to next center 462
# Moving to next center 404
# Moving to next center 128
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Better Objective found
# 145
# Succeeded in improving 222.58283084570104
# The best basic unit is 145
# Moving to next center 357
# Better Objective found
# 491
# Succeeded in improving 222.57463074797278
# The best basic unit is 491
# Moving to next center 702
# Moving to next center 470
# Better Objective found
# 438
# Succeeded in improving 222.5688949620196
# The best basic unit is 438
# Moving to next center 481
# Better Objective found
# 261
# Succeeded in improving 222.53094920531697
# The best basic unit is 261
# Repeating the for loop again
# 222.53094920531697
# Moving to next center 462
# Moving to next center 404
# Moving to next center 128
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Better Objective found
# 118
# Succeeded in improving 222.47364690260238
# The best basic unit is 118
# Moving to next center 357
# Better Objective found
# 252
# Succeeded in improving 222.45808675765022
# The best basic unit is 252
# Moving to next center 702
# Moving to next center 470
# Better Objective found
# 437
# Succeeded in improving 222.4535366464064
# The best basic unit is 437
# Moving to next center 481
# Better Objective found
# 263
# Succeeded in improving 222.4291074543816
# The best basic unit is 263
# Repeating the for loop again
# 222.4291074543816
# Moving to next center 462
# Moving to next center 404
# Moving to next center 128
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Better Objective found
# 144
# Succeeded in improving 222.3687862420957
# The best basic unit is 144
# Moving to next center 357
# Better Objective found
# 465
# Succeeded in improving 222.36558625441037
# The best basic unit is 465
# Moving to next center 702
# Moving to next center 470
# Better Objective found
# 589
# Succeeded in improving 222.3638665781292
# The best basic unit is 589
# Moving to next center 481
# Better Objective found
# 236
# Succeeded in improving 222.3286031636892
# The best basic unit is 236
# Repeating the for loop again
# 222.3286031636892
# Moving to next center 462
# Moving to next center 404
# Moving to next center 128
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Better Objective found
# 91
# Succeeded in improving 222.28039770200482
# The best basic unit is 91
# Moving to next center 357
# Better Objective found
# 359
# Succeeded in improving 222.2766719707745
# The best basic unit is 359
# Moving to next center 702
# Moving to next center 470
# Moving to next center 481
# Better Objective found
# 237
# Succeeded in improving 222.26174834897486
# The best basic unit is 237
# Repeating the for loop again
# 222.26174834897486
# Moving to next center 462
# Moving to next center 404
# Moving to next center 128
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Better Objective found
# 117
# Succeeded in improving 222.2193817198632
# The best basic unit is 117
# Moving to next center 357
# Better Objective found
# 251
# Succeeded in improving 222.2125151061739
# The best basic unit is 251
# Moving to next center 702
# Moving to next center 470
# Moving to next center 481
# Better Objective found
# 398
# Succeeded in improving 222.1197248406142
# The best basic unit is 398
# Repeating the for loop again
# 222.1197248406142
# Moving to next center 462
# Moving to next center 404
# Moving to next center 128
# Moving to next center 314
# Moving to next center 645
# Better Objective found
# 511
# Succeeded in improving 222.11873537633178
# The best basic unit is 511
# Moving to next center 282
# Better Objective found
# 64
# Succeeded in improving 222.0616985112346
# The best basic unit is 64
# Moving to next center 357
# Moving to next center 702
# Moving to next center 470
# Better Objective found
# 616
# Succeeded in improving 222.0612697363781
# The best basic unit is 616
# Moving to next center 481
# Better Objective found
# 234
# Succeeded in improving 222.04329502643478
# The best basic unit is 234
# Repeating the for loop again
# 222.04329502643478
# Moving to next center 462
# Moving to next center 404
# Moving to next center 128
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Better Objective found
# 90
# Succeeded in improving 221.97703835794735
# The best basic unit is 90
# Moving to next center 357
# Moving to next center 702
# Moving to next center 470
# Better Objective found
# 617
# Succeeded in improving 221.9753568222525
# The best basic unit is 617
# Moving to next center 481
# Better Objective found
# 422
# Succeeded in improving 221.94965441556772
# The best basic unit is 422
# Repeating the for loop again
# 221.94965441556772
# Moving to next center 462
# Moving to next center 404
# Moving to next center 128
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Better Objective found
# 37
# Succeeded in improving 221.91473208852724
# The best basic unit is 37
# Moving to next center 357
# Better Objective found
# 387
# Succeeded in improving 221.91356630028014
# The best basic unit is 387
# Moving to next center 702
# Moving to next center 470
# Better Objective found
# 387
# Succeeded in improving 221.90302640290852
# The best basic unit is 387
# Moving to next center 481
# Better Objective found
# 233
# Succeeded in improving 221.8939416266372
# The best basic unit is 233
# Repeating the for loop again
# 221.8939416266372
# Moving to next center 462
# Moving to next center 404
# Moving to next center 128
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Better Objective found
# 63
# Succeeded in improving 221.84707918786123
# The best basic unit is 63
# Moving to next center 357
# Better Objective found
# 277
# Succeeded in improving 221.84591339961412
# The best basic unit is 277
# Moving to next center 702
# Moving to next center 470
# Better Objective found
# 360
# Succeeded in improving 221.83303714543354
# The best basic unit is 360
# Moving to next center 481
# Better Objective found
# 449
# Succeeded in improving 194.17262406586224
# The best basic unit is 449
# Repeating the for loop again
# 194.17262406586224
# Moving to next center 462
# Moving to next center 404
# Moving to next center 128
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Better Objective found
# 89
# Succeeded in improving 194.14441525306637
# The best basic unit is 89
# Moving to next center 357
# Moving to next center 702
# Moving to next center 470
# Better Objective found
# 386
# Succeeded in improving 194.14195705908645
# The best basic unit is 386
# Moving to next center 481
# Better Objective found
# 231
# Succeeded in improving 194.12358981303913
# The best basic unit is 231
# Repeating the for loop again
# 194.12358981303913
# Moving to next center 462
# Moving to next center 404
# Moving to next center 128
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Moving to next center 357
# Moving to next center 702
# Moving to next center 470
# Moving to next center 481
# Better Objective found
# 230
# Succeeded in improving 194.11876560143983
# The best basic unit is 230
# Repeating the for loop again
# 194.11876560143983
# Moving to next center 462
# Moving to next center 404
# Moving to next center 128
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Moving to next center 357
# Moving to next center 702
# Moving to next center 470
# Moving to next center 481
# Better Objective found
# 560
# Succeeded in improving 194.11408332719233
# The best basic unit is 560
# Repeating the for loop again
# 194.11408332719233
# Moving to next center 462
# Moving to next center 404
# Moving to next center 128
# Moving to next center 314
# Moving to next center 645
# Better Objective found
# 508
# Succeeded in improving 194.10440109493416
# The best basic unit is 508
# Moving to next center 282
# Moving to next center 357
# Moving to next center 702
# Moving to next center 470
# Moving to next center 481
# Better Objective found
# 537
# Succeeded in improving 194.09819822855337
# The best basic unit is 537
# Repeating the for loop again
# 194.09819822855337
# Moving to next center 462
# Moving to next center 404
# Moving to next center 128
# Moving to next center 314
# Moving to next center 645
# Better Objective found
# 510
# Succeeded in improving 194.09654731848585
# The best basic unit is 510
# Moving to next center 282
# Moving to next center 357
# Moving to next center 702
# Moving to next center 470
# Moving to next center 481
# Better Objective found
# 561
# Succeeded in improving 194.08952390711462
# The best basic unit is 561
# Repeating the for loop again
# 194.08952390711462
# Moving to next center 462
# Moving to next center 404
# Moving to next center 128
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Better Objective found
# 231
# Succeeded in improving 194.08511661825534
# The best basic unit is 231
# Moving to next center 357
# Moving to next center 702
# Moving to next center 470
# Moving to next center 481
# Better Objective found
# 562
# Succeeded in improving 194.0817219694259
# The best basic unit is 562
# Repeating the for loop again
# 194.0817219694259
# Moving to next center 462
# Moving to next center 404
# Moving to next center 128
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Moving to next center 357
# Moving to next center 702
# Moving to next center 470
# Better Objective found
# 333
# Succeeded in improving 194.07787216244319
# The best basic unit is 333
# Moving to next center 481
# Better Objective found
# 535
# Succeeded in improving 194.07223848105016
# The best basic unit is 535
# Repeating the for loop again
# 194.07223848105016
# Moving to next center 462
# Moving to next center 404
# Moving to next center 128
# Moving to next center 314
# Moving to next center 645
# Moving to next center 282
# Moving to next center 357
# Moving to next center 702
# Moving to next center 470
# Moving to next center 481
# Local Optimum Reached

# %%
#Best Improvement
local_obj, local_infeasible, local_sol = localsearch_grasp(district,centers_depots,combinations,adjacent_nodes,average_customers, average_demand,average_workload,shortest_paths_dict,0.3,0.05,G1)
# Out:
# Repeating the for loop again
# The current best objective is 140.7459365939455
# Moving to next center 143
# Moving to next center 184
# Moving to next center 694
# Better Objective found
# 529
# Better Objective found
# 591
# Better Objective found
# 620
# Succeeded in improving 140.7162103305835
# The best basic unit is 620
# Moving to next center 467
# Better Objective found
# 461
# Succeeded in improving 137.45958722303448
# The best basic unit is 461
# Moving to next center 28
# Better Objective found
# 193
# Better Objective found
# 221
# Better Objective found
# 32
# Succeeded in improving 137.4098003243979
# The best basic unit is 32
# Moving to next center 258
# Better Objective found
# 223
# Better Objective found
# 333
# Better Objective found
# 359
# Better Objective found
# 466
# Succeeded in improving 137.3496944674145
# The best basic unit is 466
# Moving to next center 197
# Better Objective found
# 144
# Better Objective found
# 116
# Succeeded in improving 137.27219058758104
# The best basic unit is 116
# Moving to next center 352
# Better Objective found
# 245
# Better Objective found
# 271
# Better Objective found
# 301
# Better Objective found
# 328
# Better Objective found
# 355
# Better Objective found
# 461
# Succeeded in improving 137.18543680267908
# The best basic unit is 461
# Moving to next center 565
# Moving to next center 316
# Better Objective found
# 292
# Better Objective found
# 400
# Succeeded in improving 137.0668120083605
# The best basic unit is 400
# Repeating the for loop again
# The current best objective is 137.0668120083605
# Moving to next center 143
# Better Objective found
# 201
# Succeeded in improving 137.0544889217017
# The best basic unit is 201
# Moving to next center 184
# Moving to next center 694
# Better Objective found
# 529
# Succeeded in improving 137.03788361036442
# The best basic unit is 529
# Moving to next center 467
# Moving to next center 28
# Better Objective found
# 33
# Better Objective found
# 59
# Better Objective found
# 193
# Better Objective found
# 221
# Better Objective found
# 6
# Better Objective found
# 329
# Succeeded in improving 137.00588330714555
# The best basic unit is 329
# Moving to next center 258
# Better Objective found
# 493
# Succeeded in improving 136.9535875448616
# The best basic unit is 493
# Moving to next center 197
# Better Objective found
# 144
# Succeeded in improving 136.88618088769482
# The best basic unit is 144
# Moving to next center 352
# Better Objective found
# 488
# Better Objective found
# 460
# Succeeded in improving 136.76900771061236
# The best basic unit is 460
# Moving to next center 565
# Better Objective found
# 266
# Succeeded in improving 136.76516143361923
# The best basic unit is 266
# Moving to next center 316
# Better Objective found
# 292
# Succeeded in improving 136.6866453857492
# The best basic unit is 292
# Repeating the for loop again
# The current best objective is 136.6866453857492
# Moving to next center 143
# Better Objective found
# 203
# Succeeded in improving 136.67713281610926
# The best basic unit is 203
# Moving to next center 184
# Moving to next center 694
# Better Objective found
# 527
# Better Objective found
# 646
# Succeeded in improving 136.6677903249484
# The best basic unit is 646
# Moving to next center 467
# Moving to next center 28
# Better Objective found
# 59
# Better Objective found
# 6
# Succeeded in improving 136.65354560377193
# The best basic unit is 6
# Moving to next center 258
# Better Objective found
# 520
# Better Objective found
# 359
# Better Objective found
# 411
# Better Objective found
# 306
# Better Objective found
# 488
# Succeeded in improving 136.61265792832788
# The best basic unit is 488
# Moving to next center 197
# Better Objective found
# 115
# Better Objective found
# 169
# Better Objective found
# 142
# Better Objective found
# 252
# Better Objective found
# 251
# Succeeded in improving 136.56275971094288
# The best basic unit is 251
# Moving to next center 352
# Better Objective found
# 488
# Better Objective found
# 487
# Succeeded in improving 136.49288277847842
# The best basic unit is 487
# Moving to next center 565
# Better Objective found
# 265
# Succeeded in improving 136.48231267637587
# The best basic unit is 265
# Moving to next center 316
# Better Objective found
# 265
# Succeeded in improving 136.38522082626287
# The best basic unit is 265
# Repeating the for loop again
# The current best objective is 136.38522082626287
# Moving to next center 143
# Moving to next center 184
# Moving to next center 694
# Better Objective found
# 527
# Succeeded in improving 136.37943308289218
# The best basic unit is 527
# Moving to next center 467
# Moving to next center 28
# Moving to next center 258
# Better Objective found
# 520
# Better Objective found
# 359
# Better Objective found
# 385
# Better Objective found
# 411
# Succeeded in improving 136.35041690184678
# The best basic unit is 411
# Moving to next center 197
# Better Objective found
# 115
# Better Objective found
# 169
# Better Objective found
# 142
# Better Objective found
# 252
# Better Objective found
# 278
# Succeeded in improving 136.28613628387117
# The best basic unit is 278
# Moving to next center 352
# Better Objective found
# 488
# Better Objective found
# 486
# Succeeded in improving 136.1928101668688
# The best basic unit is 486
# Moving to next center 565
# Better Objective found
# 214
# Succeeded in improving 136.1822400647663
# The best basic unit is 214
# Moving to next center 316
# Better Objective found
# 238
# Better Objective found
# 293
# Succeeded in improving 136.09281745037288
# The best basic unit is 293
# Repeating the for loop again
# The current best objective is 136.09281745037288
# Moving to next center 143
# Moving to next center 184
# Moving to next center 694
# Better Objective found
# 500
# Succeeded in improving 136.0847304570465
# The best basic unit is 500
# Moving to next center 467
# Moving to next center 28
# Moving to next center 258
# Better Objective found
# 333
# Better Objective found
# 306
# Succeeded in improving 136.05535252711243
# The best basic unit is 306
# Moving to next center 197
# Better Objective found
# 115
# Better Objective found
# 169
# Better Objective found
# 142
# Better Objective found
# 279
# Better Objective found
# 305
# Succeeded in improving 136.0056936329158
# The best basic unit is 305
# Moving to next center 352
# Better Objective found
# 488
# Succeeded in improving 135.95436493930197
# The best basic unit is 488
# Moving to next center 565
# Better Objective found
# 213
# Succeeded in improving 135.95151478454727
# The best basic unit is 213
# Moving to next center 316
# Better Objective found
# 238
# Succeeded in improving 135.86633786799257
# The best basic unit is 238
# Repeating the for loop again
# The current best objective is 135.86633786799257
# Moving to next center 143
# Moving to next center 184
# Moving to next center 694
# Moving to next center 467
# Moving to next center 28
# Moving to next center 258
# Better Objective found
# 333
# Succeeded in improving 135.83221726482876
# The best basic unit is 333
# Moving to next center 197
# Better Objective found
# 115
# Better Objective found
# 169
# Better Objective found
# 142
# Better Objective found
# 332
# Succeeded in improving 135.77801958032558
# The best basic unit is 332
# Moving to next center 352
# Better Objective found
# 515
# Succeeded in improving 135.70032084250064
# The best basic unit is 515
# Moving to next center 565
# Moving to next center 316
# Better Objective found
# 211
# Succeeded in improving 135.5625699808903
# The best basic unit is 211
# Repeating the for loop again
# The current best objective is 135.5625699808903
# Moving to next center 143
# Moving to next center 184
# Moving to next center 694
# Moving to next center 467
# Moving to next center 28
# Moving to next center 258
# Better Objective found
# 360
# Succeeded in improving 135.53029006454702
# The best basic unit is 360
# Moving to next center 197
# Better Objective found
# 115
# Better Objective found
# 169
# Better Objective found
# 142
# Better Objective found
# 333
# Better Objective found
# 359
# Succeeded in improving 135.42219420505452
# The best basic unit is 359
# Moving to next center 352
# Better Objective found
# 516
# Succeeded in improving 135.3315963826388
# The best basic unit is 516
# Moving to next center 565
# Moving to next center 316
# Better Objective found
# 210
# Succeeded in improving 135.22981982225795
# The best basic unit is 210
# Repeating the for loop again
# The current best objective is 135.22981982225795
# Moving to next center 143
# Better Objective found
# 230
# Better Objective found
# 250
# Succeeded in improving 135.22309294862367
# The best basic unit is 250
# Moving to next center 184
# Moving to next center 694
# Moving to next center 467
# Moving to next center 28
# Moving to next center 258
# Better Objective found
# 387
# Succeeded in improving 135.20414985971976
# The best basic unit is 387
# Moving to next center 197
# Better Objective found
# 115
# Better Objective found
# 169
# Better Objective found
# 142
# Better Objective found
# 386
# Succeeded in improving 135.10977181991748
# The best basic unit is 386
# Moving to next center 352
# Better Objective found
# 543
# Succeeded in improving 135.03083692445094
# The best basic unit is 543
# Moving to next center 565
# Moving to next center 316
# Better Objective found
# 212
# Better Objective found
# 183
# Succeeded in improving 134.92696992611428
# The best basic unit is 183
# Repeating the for loop again
# The current best objective is 134.92696992611428
# Moving to next center 143
# Better Objective found
# 230
# Better Objective found
# 277
# Succeeded in improving 134.9203808558936
# The best basic unit is 277
# Moving to next center 184
# Moving to next center 694
# Moving to next center 467
# Moving to next center 28
# Moving to next center 258
# Better Objective found
# 414
# Better Objective found
# 388
# Succeeded in improving 134.87729847152605
# The best basic unit is 388
# Moving to next center 197
# Better Objective found
# 115
# Better Objective found
# 169
# Better Objective found
# 142
# Better Objective found
# 413
# Succeeded in improving 134.79025123078708
# The best basic unit is 413
# Moving to next center 352
# Better Objective found
# 570
# Better Objective found
# 542
# Succeeded in improving 134.71738456733223
# The best basic unit is 542
# Moving to next center 565
# Moving to next center 316
# Better Objective found
# 212
# Better Objective found
# 237
# Better Objective found
# 266
# Succeeded in improving 134.63646598778905
# The best basic unit is 266
# Repeating the for loop again
# The current best objective is 134.63646598778905
# Moving to next center 143
# Better Objective found
# 230
# Better Objective found
# 304
# Succeeded in improving 134.63136726148633
# The best basic unit is 304
# Moving to next center 184
# Moving to next center 694
# Moving to next center 467
# Moving to next center 28
# Moving to next center 258
# Better Objective found
# 414
# Better Objective found
# 415
# Succeeded in improving 134.60264674845982
# The best basic unit is 415
# Moving to next center 197
# Better Objective found
# 115
# Better Objective found
# 169
# Better Objective found
# 142
# Better Objective found
# 414
# Better Objective found
# 412
# Succeeded in improving 134.5245086660022
# The best basic unit is 412
# Moving to next center 352
# Better Objective found
# 570
# Better Objective found
# 569
# Succeeded in improving 134.43245556181674
# The best basic unit is 569
# Moving to next center 565
# Moving to next center 316
# Better Objective found
# 212
# Better Objective found
# 237
# Succeeded in improving 134.35887145005097
# The best basic unit is 237
# Repeating the for loop again
# The current best objective is 134.35887145005097
# Moving to next center 143
# Better Objective found
# 230
# Better Objective found
# 331
# Succeeded in improving 134.35390846158137
# The best basic unit is 331
# Moving to next center 184
# Moving to next center 694
# Moving to next center 467
# Moving to next center 28
# Better Objective found
# 59
# Succeeded in improving 134.34835460303617
# The best basic unit is 59
# Moving to next center 258
# Better Objective found
# 442
# Succeeded in improving 134.31846646261647
# The best basic unit is 442
# Moving to next center 197
# Better Objective found
# 115
# Better Objective found
# 169
# Better Objective found
# 142
# Better Objective found
# 414
# Better Objective found
# 385
# Succeeded in improving 134.24098684891968
# The best basic unit is 385
# Moving to next center 352
# Better Objective found
# 570
# Better Objective found
# 568
# Succeeded in improving 134.14843487488181
# The best basic unit is 568
# Moving to next center 565
# Moving to next center 316
# Better Objective found
# 212
# Better Objective found
# 452
# Succeeded in improving 134.08553164548943
# The best basic unit is 452
# Repeating the for loop again
# The current best objective is 134.08553164548943
# Moving to next center 143
# Moving to next center 184
# Moving to next center 694
# Moving to next center 467
# Moving to next center 28
# Moving to next center 258
# Better Objective found
# 441
# Better Objective found
# 414
# Better Objective found
# 443
# Succeeded in improving 134.06655091815074
# The best basic unit is 443
# Moving to next center 197
# Better Objective found
# 115
# Better Objective found
# 169
# Better Objective found
# 142
# Better Objective found
# 414
# Better Objective found
# 360
# Better Objective found
# 411
# Better Objective found
# 252
# Better Objective found
# 358
# Better Objective found
# 384
# Succeeded in improving 133.9647415368437
# The best basic unit is 384
# Moving to next center 352
# Better Objective found
# 570
# Better Objective found
# 595
# Succeeded in improving 133.8696155563675
# The best basic unit is 595
# Moving to next center 565
# Moving to next center 316
# Better Objective found
# 212
# Better Objective found
# 479
# Succeeded in improving 133.80923955650434
# The best basic unit is 479
# Repeating the for loop again
# The current best objective is 133.80923955650434
# Moving to next center 143
# Moving to next center 184
# Moving to next center 694
# Better Objective found
# 496
# Succeeded in improving 133.80266840072744
# The best basic unit is 496
# Moving to next center 467
# Moving to next center 28
# Moving to next center 258
# Better Objective found
# 441
# Better Objective found
# 414
# Better Objective found
# 444
# Better Objective found
# 470
# Succeeded in improving 133.78342445517973
# The best basic unit is 470
# Moving to next center 197
# Better Objective found
# 115
# Better Objective found
# 169
# Better Objective found
# 142
# Better Objective found
# 414
# Better Objective found
# 411
# Better Objective found
# 358
# Succeeded in improving 133.70356749214818
# The best basic unit is 358
# Moving to next center 352
# Better Objective found
# 570
# Better Objective found
# 622
# Better Objective found
# 567
# Succeeded in improving 133.61517554020247
# The best basic unit is 567
# Moving to next center 565
# Moving to next center 316
# Better Objective found
# 212
# Better Objective found
# 506
# Better Objective found
# 363
# Better Objective found
# 392
# Succeeded in improving 133.55862989426188
# The best basic unit is 392
# Repeating the for loop again
# The current best objective is 133.55862989426188
# Moving to next center 143
# Moving to next center 184
# Moving to next center 694
# Moving to next center 467
# Moving to next center 28
# Moving to next center 258
# Better Objective found
# 441
# Succeeded in improving 133.5488433396032
# The best basic unit is 441
# Moving to next center 197
# Better Objective found
# 115
# Better Objective found
# 169
# Better Objective found
# 142
# Better Objective found
# 414
# Succeeded in improving 133.47685617414692
# The best basic unit is 414
# Moving to next center 352
# Better Objective found
# 570
# Better Objective found
# 622
# Better Objective found
# 540
# Succeeded in improving 133.37054109143898
# The best basic unit is 540
# Moving to next center 565
# Moving to next center 316
# Better Objective found
# 212
# Better Objective found
# 506
# Better Objective found
# 391
# Succeeded in improving 133.30887969622262
# The best basic unit is 391
# Repeating the for loop again
# The current best objective is 133.30887969622262
# Moving to next center 143
# Better Objective found
# 230
# Better Objective found
# 330
# Succeeded in improving 133.29720724206652
# The best basic unit is 330
# Moving to next center 184
# Moving to next center 694
# Moving to next center 467
# Moving to next center 28
# Better Objective found
# 60
# Succeeded in improving 133.28770395949562
# The best basic unit is 60
# Moving to next center 258
# Better Objective found
# 468
# Succeeded in improving 133.267951193211
# The best basic unit is 468
# Moving to next center 197
# Better Objective found
# 115
# Better Objective found
# 169
# Better Objective found
# 142
# Better Objective found
# 415
# Better Objective found
# 360
# Better Objective found
# 411
# Succeeded in improving 133.18861978647732
# The best basic unit is 411
# Moving to next center 352
# Better Objective found
# 570
# Better Objective found
# 622
# Succeeded in improving 133.10815038101092
# The best basic unit is 622
# Moving to next center 565
# Moving to next center 316
# Better Objective found
# 212
# Better Objective found
# 506
# Better Objective found
# 389
# Better Objective found
# 363
# Better Objective found
# 372
# Succeeded in improving 133.05932045126397
# The best basic unit is 372
# Repeating the for loop again
# The current best objective is 133.05932045126397
# Moving to next center 143
# Moving to next center 184
# Moving to next center 694
# Moving to next center 467
# Moving to next center 28
# Moving to next center 258
# Moving to next center 197
# Better Objective found
# 115
# Better Objective found
# 169
# Better Objective found
# 142
# Succeeded in improving 132.9907035717741
# The best basic unit is 142
# Moving to next center 352
# Better Objective found
# 623
# Better Objective found
# 570
# Better Objective found
# 649
# Succeeded in improving 132.88622766332958
# The best basic unit is 649
# Moving to next center 565
# Better Objective found
# 617
# Succeeded in improving 132.8858576611641
# The best basic unit is 617
# Moving to next center 316
# Better Objective found
# 212
# Better Objective found
# 263
# Better Objective found
# 506
# Better Objective found
# 389
# Better Objective found
# 363
# Succeeded in improving 132.8544991981497
# The best basic unit is 363
# Repeating the for loop again
# The current best objective is 132.8544991981497
# Moving to next center 143
# Moving to next center 184
# Moving to next center 694
# Moving to next center 467
# Moving to next center 28
# Moving to next center 258
# Moving to next center 197
# Better Objective found
# 115
# Better Objective found
# 169
# Better Objective found
# 141
# Better Objective found
# 226
# Better Objective found
# 410
# Succeeded in improving 132.79747074429258
# The best basic unit is 410
# Moving to next center 352
# Better Objective found
# 623
# Better Objective found
# 570
# Better Objective found
# 650
# Better Objective found
# 594
# Better Objective found
# 648
# Better Objective found
# 517
# Succeeded in improving 130.96361050671058
# The best basic unit is 517
# Moving to next center 565
# Moving to next center 316
# Better Objective found
# 212
# Better Objective found
# 263
# Better Objective found
# 506
# Better Objective found
# 389
# Better Objective found
# 362
# Succeeded in improving 130.91325187047954
# The best basic unit is 362
# Repeating the for loop again
# The current best objective is 130.91325187047954
# Moving to next center 143
# Moving to next center 184
# Moving to next center 694
# Moving to next center 467
# Moving to next center 28
# Moving to next center 258
# Better Objective found
# 495
# Better Objective found
# 444
# Succeeded in improving 129.68586068928468
# The best basic unit is 444
# Moving to next center 197
# Better Objective found
# 115
# Better Objective found
# 169
# Better Objective found
# 141
# Better Objective found
# 226
# Succeeded in improving 129.63014041321682
# The best basic unit is 226
# Moving to next center 352
# Better Objective found
# 623
# Better Objective found
# 570
# Better Objective found
# 650
# Better Objective found
# 594
# Better Objective found
# 648
# Better Objective found
# 408
# Succeeded in improving 128.68036289106735
# The best basic unit is 408
# Moving to next center 565
# Moving to next center 316
# Better Objective found
# 506
# Better Objective found
# 389
# Better Objective found
# 261
# Succeeded in improving 120.30358276625684
# The best basic unit is 261
# Repeating the for loop again
# The current best objective is 120.30358276625684
# Moving to next center 143
# Moving to next center 184
# Moving to next center 694
# Moving to next center 467
# Moving to next center 28
# Moving to next center 258
# Better Objective found
# 495
# Succeeded in improving 120.2625849522559
# The best basic unit is 495
# Moving to next center 197
# Better Objective found
# 115
# Better Objective found
# 169
# Better Objective found
# 141
# Succeeded in improving 120.21542572694622
# The best basic unit is 141
# Moving to next center 352
# Better Objective found
# 623
# Better Objective found
# 570
# Better Objective found
# 650
# Better Objective found
# 594
# Better Objective found
# 648
# Better Objective found
# 489
# Succeeded in improving 117.75412695709468
# The best basic unit is 489
# Moving to next center 565
# Moving to next center 316
# Better Objective found
# 506
# Better Objective found
# 389
# Succeeded in improving 117.43987482272374
# The best basic unit is 389
# Repeating the for loop again
# The current best objective is 117.43987482272374
# Moving to next center 143
# Moving to next center 184
# Moving to next center 694
# Moving to next center 467
# Moving to next center 28
# Moving to next center 258
# Better Objective found
# 389
# Succeeded in improving 117.42464754552232
# The best basic unit is 389
# Moving to next center 197
# Better Objective found
# 115
# Better Objective found
# 169
# Better Objective found
# 441
# Better Objective found
# 415
# Better Objective found
# 360
# Better Objective found
# 439
# Succeeded in improving 117.38286343744781
# The best basic unit is 439
# Moving to next center 352
# Better Objective found
# 623
# Better Objective found
# 570
# Better Objective found
# 650
# Better Objective found
# 594
# Better Objective found
# 648
# Succeeded in improving 117.2636578305493
# The best basic unit is 648
# Moving to next center 565
# Moving to next center 316
# Better Objective found
# 506
# Better Objective found
# 234
# Succeeded in improving 115.78095215895452
# The best basic unit is 234
# Repeating the for loop again
# The current best objective is 115.78095215895452
# Moving to next center 143
# Moving to next center 184
# Moving to next center 694
# Moving to next center 467
# Moving to next center 28
# Moving to next center 258
# Better Objective found
# 522
# Better Objective found
# 496
# Better Objective found
# 362
# Succeeded in improving 114.55621644621559
# The best basic unit is 362
# Moving to next center 197
# Better Objective found
# 115
# Better Objective found
# 169
# Better Objective found
# 441
# Better Objective found
# 415
# Better Objective found
# 360
# Better Objective found
# 466
# Succeeded in improving 114.48885651961417
# The best basic unit is 466
# Moving to next center 352
# Better Objective found
# 623
# Better Objective found
# 594
# Succeeded in improving 114.4160362684196
# The best basic unit is 594
# Moving to next center 565
# Moving to next center 316
# Better Objective found
# 506
# Better Objective found
# 373
# Better Objective found
# 320
# Better Objective found
# 319
# Succeeded in improving 114.39630414159218
# The best basic unit is 319
# Repeating the for loop again
# The current best objective is 114.39630414159218
# Moving to next center 143
# Moving to next center 184
# Moving to next center 694
# Moving to next center 467
# Moving to next center 28
# Moving to next center 258
# Better Objective found
# 522
# Better Objective found
# 496
# Succeeded in improving 114.35483665558887
# The best basic unit is 496
# Moving to next center 197
# Better Objective found
# 115
# Better Objective found
# 169
# Better Objective found
# 441
# Better Objective found
# 360
# Better Objective found
# 493
# Succeeded in improving 114.30134280680218
# The best basic unit is 493
# Moving to next center 352
# Better Objective found
# 623
# Succeeded in improving 114.2467728128636
# The best basic unit is 623
# Moving to next center 565
# Moving to next center 316
# Better Objective found
# 506
# Succeeded in improving 114.24420369075773
# The best basic unit is 506
# Repeating the for loop again
# The current best objective is 114.24420369075773
# Moving to next center 143
# Moving to next center 184
# Moving to next center 694
# Moving to next center 467
# Moving to next center 28
# Moving to next center 258
# Better Objective found
# 522
# Succeeded in improving 114.22080848571835
# The best basic unit is 522
# Moving to next center 197
# Better Objective found
# 115
# Better Objective found
# 169
# Better Objective found
# 441
# Better Objective found
# 415
# Better Objective found
# 360
# Better Objective found
# 492
# Succeeded in improving 114.17333805017589
# The best basic unit is 492
# Moving to next center 352
# Better Objective found
# 624
# Succeeded in improving 114.09950110518712
# The best basic unit is 624
# Moving to next center 565
# Moving to next center 316
# Better Objective found
# 373
# Succeeded in improving 114.09863949402252
# The best basic unit is 373
# Repeating the for loop again
# The current best objective is 114.09863949402252
# Moving to next center 143
# Moving to next center 184
# Moving to next center 694
# Moving to next center 467
# Moving to next center 28
# Moving to next center 258
# Better Objective found
# 391
# Succeeded in improving 114.08543161196295
# The best basic unit is 391
# Moving to next center 197
# Better Objective found
# 115
# Better Objective found
# 169
# Better Objective found
# 441
# Better Objective found
# 415
# Better Objective found
# 360
# Better Objective found
# 279
# Better Objective found
# 491
# Succeeded in improving 114.03678102394122
# The best basic unit is 491
# Moving to next center 352
# Better Objective found
# 625
# Better Objective found
# 570
# Succeeded in improving 113.99039545755463
# The best basic unit is 570
# Moving to next center 565
# Better Objective found
# 616
# Succeeded in improving 113.98532703744634
# The best basic unit is 616
# Moving to next center 316
# Better Objective found
# 505
# Better Objective found
# 320
# Better Objective found
# 346
# Succeeded in improving 113.97154173936067
# The best basic unit is 346
# Repeating the for loop again
# The current best objective is 113.97154173936067
# Moving to next center 143
# Moving to next center 184
# Moving to next center 694
# Moving to next center 467
# Moving to next center 28
# Moving to next center 258
# Better Objective found
# 363
# Succeeded in improving 113.95803265715077
# The best basic unit is 363
# Moving to next center 197
# Better Objective found
# 115
# Better Objective found
# 169
# Better Objective found
# 441
# Better Objective found
# 415
# Better Objective found
# 306
# Better Objective found
# 252
# Succeeded in improving 113.91829903502153
# The best basic unit is 252
# Moving to next center 352
# Better Objective found
# 625
# Better Objective found
# 571
# Better Objective found
# 650
# Better Objective found
# 301
# Succeeded in improving 113.87530986958798
# The best basic unit is 301
# Moving to next center 565
# Better Objective found
# 618
# Succeeded in improving 113.87256547353914
# The best basic unit is 618
# Moving to next center 316
# Better Objective found
# 347
# Better Objective found
# 320
# Succeeded in improving 113.86643040500762
# The best basic unit is 320
# Repeating the for loop again
# The current best objective is 113.86643040500762
# Moving to next center 143
# Moving to next center 184
# Moving to next center 694
# Moving to next center 467
# Moving to next center 28
# Moving to next center 258
# Better Objective found
# 392
# Succeeded in improving 113.85528071294478
# The best basic unit is 392
# Moving to next center 197
# Better Objective found
# 115
# Better Objective found
# 169
# Better Objective found
# 441
# Better Objective found
# 415
# Better Objective found
# 306
# Succeeded in improving 113.81802198830873
# The best basic unit is 306
# Moving to next center 352
# Better Objective found
# 625
# Better Objective found
# 571
# Better Objective found
# 650
# Succeeded in improving 113.77716021895202
# The best basic unit is 650
# Moving to next center 565
# Moving to next center 316
# Local Optimum Reached

# %%
#GRASP LS
local_obj, local_infeasible, local_sol = localsearch_grasp(district,centers_depots,combinations,adjacent_nodes,average_customers, average_demand,average_workload,shortest_paths_dict,0.3,0.05,G1)
# Out:
# Local Optimum Reached

# %%
print(construction_infeasible)
print(construction_obj)
# Out:
# 3.6547806408067856
# 386

# %%
#First Improvement
print(local_infeasible)
print(local_obj)
# Out:
# 1.6746264015002086
# 643

# %%
#Best Improvement
print(local_infeasible)
print(local_obj)
# Out:
# 0.9673717413600307
# 377

# %%
#Best Improvement depots
print(local_infeasible)
print(local_obj)
# Out:
# 0.02751071105387956
# 434

# %%
#First Improvement depots
print(local_infeasible)
print(local_obj)
# Out:
# 1.3404450787336417
# 440

# %%
#GRASP LS
print(local_infeasible)
print(local_obj)
# Out:
# 4.972360438843379
# 735

# %%
for k in centers_depots:
    for i in local_sol[k]:
        print(list(any(i in val for val in local_sol.values())))
# Out:
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [True, False, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, True, False, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, True, False, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, True, False, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, True, False, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, True, False, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, True, False, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, True, False, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, True, False]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]
# [False, False, False, False, False, False, False, False, False, True]

# %%
centers_depots
# Out:
# [462, 106, 644, 216, 712, 317, 88, 479, 443, 382]

# %%
#Three centers equal distribution
districts_keys = list(district.keys())
colorss = ["lightcoral","sandybrown","darkorange","lawngreen","green","aqua","steelblue","violet","purple","maroon"]

color_map = {}
for node in list(G1.nodes):
    color_map[node] = "blue"
    for k in range(len(districts_keys)):
        if node in district[districts_keys[k]]:
            color_map[node] = colorss[k]

color_map = list(color_map.values())

plt.figure(3,figsize=(12,12))
nx.draw(G1,node_color=color_map, pos=grid_pos,with_labels = True)
plt.show()

# %%
input_solutions = [input_one,input_two,input_three]

# %%
input_solutions_graphtwo = [input_one_graphtwo,input_two_graphtwo,input_three_graphtwo]

# %%
input_solutions_graphthree = [input_one_graphthree,input_two_graphthree,input_three_graphthree]

# %%
local_search_storage = {}

# %%
local_search_storage_graphtwo = {}

# %%
local_search_storage_graphthree = {}

# %%
district, centers_depots, combinations, adjacent_nodes, average_customers, average_demand,average_workload,shortest_paths_dict, construction_obj,construction_infeasible = input_two

# %%
for inp_sol in range(len(input_solutions_graphthree)):
    print(inp_sol)
    district, centers_depots, combinations, adjacent_nodes, average_customers, average_demand,average_workload,shortest_paths_dict, construction_obj,construction_infeasible = input_solutions_graphthree[inp_sol]
    local_search_storage_graphthree[inp_sol] = []
    ls_nb = local_obj_node_best_improvement, local_infeasible_node_best_improvement, local_sol_node_best_improvement = localsearch_node_best_improvement(district,centers_depots,combinations,adjacent_nodes,average_customers, average_demand,average_workload,shortest_paths_dict,0.3,0.05,G1)
    ls_nf = local_obj_node_first_improvement, local_infeasible_node_first_improvement, local_sol_node_first_improvement = localsearch_node_first_improvement(district,centers_depots,combinations,adjacent_nodes,average_customers, average_demand,average_workload,shortest_paths_dict,0.3,0.05,G1)
    ls_db = local_obj_depot_best_improvement, local_infeasible_depot_best_improvement, local_sol_depot_best_improvement = localsearch_depot_best_improvement(district,centers_depots,combinations,adjacent_nodes,average_customers, average_demand,average_workload,shortest_paths_dict,0.3,0.05,G1)
    ls_df = local_obj_depot_first_improvement, local_infeasible_depot_first_improvement, local_sol_depot_first_improvement = localsearch_depot_first_improvement(district,centers_depots,combinations,adjacent_nodes,average_customers, average_demand,average_workload,shortest_paths_dict,0.3,0.05,G1)
    local_search_storage_graphthree[inp_sol].append(ls_nb)
    local_search_storage_graphthree[inp_sol].append(ls_nf)
    local_search_storage_graphthree[inp_sol].append(ls_db)
    local_search_storage_graphthree[inp_sol].append(ls_df)
# Out:
# 0
# Local Optimum Reached
# Local Optimum Reached
# Local Optimum Reached
# Local Optimum Reached
# 1
# Local Optimum Reached
# Local Optimum Reached
# Local Optimum Reached
# Local Optimum Reached
# 2
# Local Optimum Reached
# Local Optimum Reached
# Local Optimum Reached
# Local Optimum Reached

# %%
local_search_storage[0][3]
# Out:
# (444,
#  3.2163535049289047,
#  {143: [144,
#    115,
#    116,
#    169,
#    141,
#    142,
#    140,
#    168,
#    88,
#    114,
#    145,
#    87,
#    117,
#    195,
#    89,
#    113,
#    167,
#    61,
#    118,
#    172,
#    60,
#    86,
#    90,
#    194,
#    62,
#    112,
#    166,
#    91,
#    119,
#    199,
#    59,
#    85,
#    63,
#    193,
#    35,
#    64,
#    92,
#    200,
#    226,
#    84,
#    36,
#    37,
#    93,
#    27,
#    30,
#    55,
#    56,
#    201,
#    203,
#    230,
#    231,
#    233,
#    250,
#    251,
#    306,
#    332,
#    333,
#    359,
#    360],
#   184: [130,
#    131,
#    210,
#    211,
#    212,
#    183,
#    185,
#    156,
#    157,
#    158,
#    129,
#    155,
#    103,
#    237,
#    186,
#    104,
#    77,
#    265,
#    132,
#    213,
#    182,
#    102,
#    128,
#    154,
#    187,
#    105,
#    266,
#    292,
#    133,
#    214,
#    240,
#    181,
#    75,
#    101,
#    127,
#    160,
#    188,
#    106,
#    51,
#    267,
#    134,
#    215,
#    208,
#    48,
#    74,
#    161,
#    107,
#    24,
#    52,
#    80,
#    21,
#    47,
#    23,
#    25,
#    53,
#    26,
#    49,
#    261],
#   694: [721,
#    695,
#    722,
#    668,
#    723,
#    696,
#    724,
#    641,
#    669,
#    697,
#    725,
#    614,
#    640,
#    642,
#    670,
#    698,
#    726,
#    587,
#    615,
#    643,
#    671,
#    699,
#    727,
#    616,
#    644,
#    672,
#    700,
#    728,
#    589,
#    617,
#    645,
#    673,
#    701,
#    562,
#    618,
#    674,
#    535,
#    647,
#    452,
#    480,
#    508,
#    236,
#    238,
#    241,
#    481,
#    509,
#    521,
#    522,
#    523,
#    527,
#    529,
#    550,
#    646],
#   467: [577,
#    603,
#    602,
#    604,
#    630,
#    601,
#    629,
#    605,
#    631,
#    657,
#    628,
#    656,
#    658,
#    684,
#    627,
#    655,
#    683,
#    685,
#    711,
#    626,
#    682,
#    712,
#    625,
#    681,
#    709,
#    598,
#    624,
#    680,
#    597,
#    623,
#    651,
#    679,
#    707,
#    622,
#    650,
#    678,
#    706,
#    595,
#    649,
#    677,
#    705,
#    594,
#    648,
#    704,
#    621,
#    675,
#    702],
#   28: [109,
#    136,
#    135,
#    163,
#    162,
#    164,
#    190,
#    189,
#    137,
#    191,
#    217,
#    216,
#    138,
#    192,
#    218,
#    219,
#    245,
#    271,
#    220,
#    246,
#    297,
#    247,
#    273,
#    248,
#    274,
#    275,
#    301,
#    276,
#    302,
#    6,
#    7,
#    32,
#    221,
#    222,
#    234,
#    252,
#    254,
#    381,
#    385,
#    386,
#    387,
#    388,
#    389,
#    411,
#    412,
#    413,
#    414,
#    415,
#    439,
#    466,
#    488],
#   258: [283,
#    310,
#    282,
#    281,
#    280,
#    308,
#    279,
#    307,
#    278,
#    334,
#    305,
#    304,
#    331,
#    330,
#    358,
#    329,
#    357,
#    328,
#    356,
#    384,
#    355,
#    383,
#    410,
#    409,
#    437,
#    436,
#    438,
#    464,
#    465,
#    284,
#    270,
#    362,
#    363,
#    391,
#    392,
#    441,
#    442,
#    443,
#    444,
#    460,
#    468,
#    470,
#    486,
#    487,
#    492,
#    493,
#    495,
#    496,
#    500,
#    514,
#    515,
#    520,
#    530,
#    540],
#   197: [224,
#    225,
#    196,
#    198,
#    170,
#    143,
#    0,
#    1,
#    2,
#    4,
#    5,
#    8,
#    9,
#    10,
#    31,
#    33,
#    34,
#    57,
#    81,
#    82,
#    83,
#    223,
#    243,
#    244,
#    277,
#    382,
#    408],
#   352: [353,
#    380,
#    325,
#    326,
#    407,
#    299,
#    327,
#    354,
#    272,
#    300,
#    406,
#    434,
#    405,
#    378,
#    432,
#    256,
#    461,
#    462,
#    463,
#    477,
#    479,
#    489,
#    491,
#    503,
#    504,
#    505,
#    506,
#    507,
#    516,
#    517,
#    518,
#    531,
#    532,
#    533,
#    541,
#    542,
#    543,
#    545,
#    546,
#    547,
#    548,
#    549,
#    559,
#    560,
#    561,
#    567,
#    568,
#    569,
#    570,
#    571,
#    573,
#    575,
#    576,
#    600,
#    654],
#   565: [592,
#    593,
#    564,
#    538,
#    619,
#    591,
#    539,
#    590,
#    537,
#    620,
#    566,
#    511,
#    512,
#    510,
#    536,
#    484,
#    485,
#    457,
#    458,
#    482,
#    430,
#    456,
#    455,
#    403,
#    428,
#    454,
#    376,
#    402,
#    349,
#    375,
#    322,
#    348,
#    374,
#    295,
#    321,
#    347,
#    373,
#    268,
#    294,
#    320,
#    346,
#    372,
#    400,
#    293,
#    319,
#    345,
#    404,
#    377,
#    350,
#    323,
#    296,
#    269,
#    78,
#    79,
#    263],
#   316: [289,
#    317,
#    343,
#    262,
#    342,
#    369,
#    315,
#    370,
#    344,
#    371,
#    290,
#    318,
#    314,
#    397,
#    398,
#    291,
#    287,
#    313,
#    424,
#    399,
#    286,
#    312,
#    422,
#    451,
#    426,
#    339,
#    449,
#    366,
#    365,
#    393,
#    420,
#    419]})

# %%
for i in local_search_storage:
    for j in local_search_storage[i]:
        print(j[1])
# Out:
# 2.695185293999336
# 4.7914930395828055
# 0.0
# 3.2163535049289047
# 6.101456987631234
# 6.585559157337605
# 0.15626566448386847
# 3.4266421692001696
# 0.12313782151365243
# 2.2140213583149744
# 0.0
# 2.599677264267359

# %%
for i in local_search_storage_graphtwo:
    for j in local_search_storage_graphtwo[i]:
        print(j[1])
# Out:
# 0.7304977647263258
# 3.4488027785036173
# 0.005696022942164099
# 3.5162012201407755
# 2.554429880641567
# 5.739590111131199
# 0.0
# 1.3940365647920994
# 1.6020491035034357
# 1.4497372116073057
# 0.0
# 2.6276199744953073

# %%
for i in local_search_storage_graphthree:
    for j in local_search_storage_graphthree[i]:
        print(j[1])
# Out:
# 12.859559556536095
# 13.11829833034057
# 0.004313731679357399
# 1.7369175380697777
# 0.7955763100735471
# 3.231134787819245
# 0.0
# 3.202787226575209
# 4.312182081707844
# 4.196631735023702
# 0.05354244081516298
# 1.2268924527828586

# %%
for i in input_solutions_graphthree:
    print(i[9])
# Out:
# 12.418190507794288
# 10.266059326939704
# 7.970830773740374

# %%
df = {'Input Graphs': ["G1-I1", "G1-I2", "G1-I3", "G2-I1", "G2-I2", "G2-I3", "G3-I1", "G3-I2", "G3-I3"],
     'Input Objective': [447,427,735,756,642,933,639,592,565],
     'Input Infeasibility': [9.49,8.20,9.31,11.324,6.97,17.33,12.42,10.27,7.97],
     'LS-NBI Objective': [430,407,643,631,519,657,619,501,565],
     'LS-NBI Infeasibility': [2.70,6.10,0.12,0.73,2.55,1.60,2.86,0.80,4.31],
     'LS-NFI Objective': [436,415,643,756,542,709,619,592,565],
     'LS-NFI Infeasibility': [4.79,6.59,2.21,3.45,5.74,1.45,3.12,3.23,4.20],
     'LS-DBI Objective': [439,424,642,712,640,905,639,584,560],
     'LS-DBI Infeasibility': [0.0,0.16,0.0,0.01,0.0,0.0,0.0,0.0,0.05],
     'LS-DFI Objective': [444,419,672,756,641,894,639,584,565],
     'LS-DFI Infeasibility':[3.12,3.43,2.60,3.52,1.39,2.63,1.74,3.20,1.23]}

# %%
df
# Out:
# {'Input Graphs': ['G1-I1',
#   'G1-I2',
#   'G1-I3',
#   'G2-I1',
#   'G2-I2',
#   'G2-I3',
#   'G3-I1',
#   'G3-I2',
#   'G3-I3'],
#  'Input Objective': [447, 427, 735, 756, 642, 933, 639, 592, 565],
#  'Input Infeasibility': [9.49,
#   8.2,
#   9.31,
#   11.324,
#   6.97,
#   17.33,
#   12.42,
#   10.27,
#   7.97],
#  'LS-NBI Objective': [430, 407, 643, 631, 519, 657, 619, 501, 565],
#  'LS-NBI Infeasibility': [2.7, 6.1, 0.12, 0.73, 2.55, 1.6, 2.86, 0.8, 4.31],
#  'LS-NFI Objective': [436, 415, 643, 756, 542, 709, 619, 592, 565],
#  'LS-NFI Infeasibility': [4.79, 6.59, 2.21, 3.45, 5.74, 1.45, 3.12, 3.23, 4.2],
#  'LS-DBI Objective': [439, 424, 642, 712, 640, 905, 639, 584, 560],
#  'LS-DBI Infeasibility': [0.0, 0.16, 0.0, 0.01, 0.0, 0.0, 0.0, 0.0, 0.05],
#  'LS-DFI Objective': [444, 419, 672, 756, 641, 894, 639, 584, 565],
#  'LS-DFI Infeasibility': [3.12, 3.43, 2.6, 3.52, 1.39, 2.63, 1.74, 3.2, 1.23]}

# %%
df = pd.DataFrame(df)

# %%
df
# Out:
#   Input Graphs  Input Objective  Input Infeasibility  LS-NBI Objective  \
# 0        G1-I1              447                9.490               430
# 1        G1-I2              427                8.200               407
# 2        G1-I3              735                9.310               643
# 3        G2-I1              756               11.324               631
# 4        G2-I2              642                6.970               519
# 5        G2-I3              933               17.330               657
# 6        G3-I1              639               12.420               619
# 7        G3-I2              592               10.270               501
# 8        G3-I3              565                7.970               565
#
#    LS-NBI Infeasibility  LS-NFI Objective  LS-NFI Infeasibility  \
# 0                  2.70               436                  4.79
# 1                  6.10               415                  6.59
# 2                  0.12               643                  2.21
# 3                  0.73               756                  3.45
# 4                  2.55               542                  5.74
# 5                  1.60               709                  1.45
# 6                  2.86               619                  3.12
# 7                  0.80               592                  3.23
# 8                  4.31               565                  4.20
#
#    LS-DBI Objective  LS-DBI Infeasibility  LS-DFI Objective  \
# 0               439                  0.00               444
# 1               424                  0.16               419
# 2               642                  0.00               672
# 3               712                  0.01               756
# 4               640                  0.00               641
# 5               905                  0.00               894
# 6               639                  0.00               639
# 7               584                  0.00               584
# 8               560                  0.05               565
#
#    LS-DFI Infeasibility  LS-NBI Objective Difference  \
# 0                  3.12                     0.038031
# 1                  3.43                     0.046838
# 2                  2.60                     0.125170
# 3                  3.52                     0.165344
# 4                  1.39                     0.191589
# 5                  2.63                     0.295820
# 6                  1.74                     0.031299
# 7                  3.20                     0.153716
# 8                  1.23                     0.000000
#
#    LS-NFI Objective Difference  LS-DBI Objective Difference  \
# 0                     0.024609                     0.017897
# 1                     0.028103                     0.007026
# 2                     0.125170                     0.126531
# 3                     0.000000                     0.058201
# 4                     0.155763                     0.003115
# 5                     0.240086                     0.030011
# 6                     0.031299                     0.000000
# 7                     0.000000                     0.013514
# 8                     0.000000                     0.008850
#
#    LS-DFI Objective Difference  LS-NBI Infeasibility Difference  \
# 0                     0.006711                         0.715490
# 1                     0.018735                         0.256098
# 2                     0.085714                         0.987111
# 3                     0.000000                         0.935535
# 4                     0.001558                         0.634146
# 5                     0.041801                         0.907675
# 6                     0.000000                         0.769726
# 7                     0.013514                         0.922103
# 8                     0.000000                         0.459222
#
#    LS-NFI Infeasibility Difference  LS-DBI Infeasibility Difference  \
# 0                         0.495258                         1.000000
# 1                         0.196341                         0.980488
# 2                         0.762621                         1.000000
# 3                         0.695337                         0.999117
# 4                         0.176471                         1.000000
# 5                         0.916330                         1.000000
# 6                         0.748792                         1.000000
# 7                         0.685492                         1.000000
# 8                         0.473024                         0.993726
#
#    LS-DFI Infeasibility Difference  Input Objective Difference
# 0                         0.671233                    0.046838
# 1                         0.581707                    0.000000
# 2                         0.720730                    0.721311
# 3                         0.689156                    0.770492
# 4                         0.800574                    0.503513
# 5                         0.848240                    1.185012
# 6                         0.859903                    0.496487
# 7                         0.688413                    0.386417
# 8                         0.845671                    0.323185

# %%
df
# Out:
#   Input Graphs  Input Objective  Input Infeasibility  LS-NBI Objective  \
# 2        G1-I3              735                 9.31               643
# 4        G2-I2              642                 6.97               519
#
#    LS-NBI Infeasibility  LS-NFI Objective  LS-NFI Infeasibility  \
# 2                  0.12               643                  2.21
# 4                  2.55               542                  5.74
#
#    LS-DBI Objective  LS-DBI Infeasibility  LS-DFI Objective  \
# 2               642                   0.0               672
# 4               640                   0.0               641
#
#    LS-DFI Infeasibility  LS-NBI Objective Difference  \
# 2                  2.60                     0.125170
# 4                  1.39                     0.191589
#
#    LS-NFI Objective Difference  LS-DBI Objective Difference  \
# 2                     0.125170                     0.126531
# 4                     0.155763                     0.003115
#
#    LS-DFI Objective Difference  LS-NBI Infeasibility Difference  \
# 2                     0.085714                         0.987111
# 4                     0.001558                         0.634146
#
#    LS-NFI Infeasibility Difference  LS-DBI Infeasibility Difference  \
# 2                         0.762621                              1.0
# 4                         0.176471                              1.0
#
#    LS-DFI Infeasibility Difference
# 2                         0.720730
# 4                         0.800574

# %%
df.mean()
# Out:
# Input Objective                    637.333333
# Input Infeasibility                 10.364889
# LS-NBI Objective                   552.444444
# LS-NBI Infeasibility                 2.418889
# LS-NFI Objective                   586.333333
# LS-NFI Infeasibility                 3.864444
# LS-DBI Objective                   616.111111
# LS-DBI Infeasibility                 0.024444
# LS-DFI Objective                   623.777778
# LS-DFI Infeasibility                 2.540000
# LS-NBI Objective Difference          0.116423
# LS-NFI Objective Difference          0.067226
# LS-DBI Objective Difference          0.029460
# LS-DFI Objective Difference          0.018670
# LS-NBI Infeasibility Difference      0.731901
# LS-NFI Infeasibility Difference      0.572185
# LS-DBI Infeasibility Difference      0.997037
# LS-DFI Infeasibility Difference      0.745070
# Input Objective Difference           0.492584
# dtype: float64

# %%
df["LS-NBI Objective Difference"] = (df["Input Objective"]-df["LS-NBI Objective"])/df["Input Objective"]
df["LS-NFI Objective Difference"] = (df["Input Objective"]-df["LS-NFI Objective"])/df["Input Objective"]
df["LS-DBI Objective Difference"] = (df["Input Objective"]-df["LS-DBI Objective"])/df["Input Objective"]
df["LS-DFI Objective Difference"] = (df["Input Objective"]-df["LS-DFI Objective"])/df["Input Objective"]

# %%
df["Input Objective Difference"] = (df["Input Objective"]-427)/427

# %%
df["LS-NBI Objective Difference"] = (df["LS-NBI Objective"]-407)/407

# %%
df["LS-NBI Infeasibility Difference"] = (df["Input Infeasibility"]-df["LS-NBI Infeasibility"])/df["Input Infeasibility"]
df["LS-NFI Infeasibility Difference"] = (df["Input Infeasibility"]-df["LS-NFI Infeasibility"])/df["Input Infeasibility"]
df["LS-DBI Infeasibility Difference"] = (df["Input Infeasibility"]-df["LS-DBI Infeasibility"])/df["Input Infeasibility"]
df["LS-DFI Infeasibility Difference"] = (df["Input Infeasibility"]-df["LS-DFI Infeasibility"])/df["Input Infeasibility"]

# %%
plt.figure(figsize=(20,20))
df.plot(x="Input Graphs", y=["Input Infeasibility", "LS-NBI Infeasibility", "LS-NFI Infeasibility","LS-DBI Infeasibility", "LS-DFI Infeasibility"],kind = "bar")
plt.xticks(rotation=0, ha='right')
plt.xlabel("Input Graphs")
plt.ylabel("Relative Infeasibility")
plt.title("Relative Infeasibility of Input Solution and Local Search Variants")
plt.figure(figsize=(20,10))
plt.show()

# %%
plt.figure(figsize=(20,20))
df.plot(x="Input Graphs", y=["Input Objective", "LS-NBI Objective", "LS-NFI Objective","LS-DBI Objective", "LS-DFI Objective"])
# plt.xticks(rotation=60, ha='right')
plt.xlabel("Input Graphs")
plt.ylabel("Objective Function Value")
plt.title("Objective Function of Input Solution and Local Search Variants")
plt.show()
